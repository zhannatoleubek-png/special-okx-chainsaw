# %% [markdown]
# <a href="https://colab.research.google.com/github/zhannatoleubek-png/special-okx-chainsaw/blob/main/long-s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -----------------------------
# MAIN LOOP (Momentum Flow Pro, все USDT пары)
# -----------------------------
# !pip install --quiet ccxt pandas numpy ta

import ccxt
import pandas as pd
import numpy as np
import time
from datetime import datetime, timezone

# -----------------------------
# CONFIG — настраиваемые параметры
# -----------------------------
CONFIG = {
    "exchange_id": "okx",
    "timeframes": {"1m":"1m","3m":"3m","5m":"5m","30m":"30m","1h":"1h"},
    "limit": 500,
    "analysis_interval_sec": 60,
    "sl_pct": 0.003,
    "tp_pct": 0.008,
    "volume_spike_mult": 1.5,
    "max_distance_from_ema50_pct": 0.01,
    "rsi_overbought": 70,
    "rsi_entry_level": 50,
    "heikin_ashi": True,
    "telegram": {
        "enabled": False,
        "bot_token": "<8294892098:AAFX0Zzq9yN1on6UlID8f7vzif4dWR_7uWs>",
        "chat_id": "<381202205>"
    }
}

# -----------------------------
# UTILS & INDICATORS
# -----------------------------
def init_exchange(cfg):
    ex_class = getattr(ccxt, cfg["exchange_id"])
    ex = ex_class({'enableRateLimit': True})
    ex.load_markets()
    return ex

def fetch_ohlcv_df(exchange, symbol, timeframe, limit=500):
    ohlcv = exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    df = pd.DataFrame(ohlcv, columns=['ts','open','high','low','close','volume'])
    df['datetime'] = pd.to_datetime(df['ts'], unit='ms', utc=True)
    df.set_index('datetime', inplace=True)
    return df

def heikin_ashi(df):
    ha = df.copy()
    ha['ha_close'] = (ha['open'] + ha['high'] + ha['low'] + ha['close'])/4
    ha['ha_open'] = 0.0
    ha.iloc[0, ha.columns.get_loc('ha_open')] = (ha.iloc[0]['open'] + ha.iloc[0]['close'])/2
    for i in range(1, len(ha)):
        ha.iat[i, ha.columns.get_loc('ha_open')] = (ha.iat[i-1, ha.columns.get_loc('ha_open')] + ha.iat[i-1, ha.columns.get_loc('ha_close')])/2
    ha['ha_high'] = ha[['ha_open','ha_close','high']].max(axis=1)
    ha['ha_low'] = ha[['ha_open','ha_close','low']].min(axis=1)
    return ha[['ha_open','ha_high','ha_low','ha_close']]

def ema(series, period):
    return series.ewm(span=period, adjust=False).mean()

def add_vwap_daily(df):
    g = df.copy()
    g['tp'] = (g['high'] + g['low'] + g['close'])/3
    g = g.groupby(g.index.date).apply(lambda gp: gp.assign(vwap=(gp['tp']*gp['volume']).cumsum()/gp['volume'].cumsum()))
    return g['vwap']

def rsi(series, period=14):
    delta = series.diff()
    up = delta.clip(lower=0)
    down = -1 * delta.clip(upper=0)
    ma_up = up.ewm(alpha=1/period, adjust=False).mean()
    ma_down = down.ewm(alpha=1/period, adjust=False).mean()
    rs = ma_up / ma_down
    return 100 - (100 / (1 + rs))

def wavetrend(df, n1=10, n2=21):
    price = (df['high'] + df['low'] + df['close'])/3
    esa = price.ewm(span=n1, adjust=False).mean()
    d = (price - esa).abs().ewm(span=n1, adjust=False).mean()
    ci = (price - esa) / (0.015 * d)
    wt1 = ci.ewm(span=n2, adjust=False).mean()
    wt2 = wt1.ewm(span=4, adjust=False).mean()
    return wt1, wt2

def mfi(df, period=14):
    typical = (df['high'] + df['low'] + df['close'])/3
    money = typical * df['volume']
    positive = (typical > typical.shift(1)).astype(int) * money
    negative = (typical < typical.shift(1)).astype(int) * money
    pos_sum = positive.rolling(period).sum()
    neg_sum = negative.rolling(period).sum()
    mfr = pos_sum / (neg_sum.replace(0, np.nan))
    return 100 - (100 / (1 + mfr)).fillna(50)

def detect_green_dot(df):
    wt1, wt2 = wavetrend(df)
    df['wt1'] = wt1
    df['wt2'] = wt2
    df['wt_cross_up'] = (df['wt1'] > df['wt2']) & (df['wt1'].shift(1) <= df['wt2'].shift(1))
    df['wt_rising'] = df['wt1'].diff() > 0
    df['mfi'] = mfi(df)
    df['rsi'] = rsi(df['close'])
    df['green_dot'] = df['wt_cross_up'] & (df['mfi'] > df['mfi'].shift(1)) & (df['rsi'] > 45)
    return df

# -----------------------------
# SIGNAL LOGIC
# -----------------------------
def analyze_pair(exchange, symbol, cfg):
    dfs = {}
    now = None
    for label, tf in cfg['timeframes'].items():
        try:
            df = fetch_ohlcv_df(exchange, symbol, tf, limit=cfg['limit'])
        except:
            continue
        dfs[label] = df
        if now is None and len(df):
            now = df.index[-1]
    if '1h' not in dfs or '30m' not in dfs:
        return {"signal":None,"reason":"Missing H1 or M30 data","time":now.isoformat() if now else None}
    h1 = dfs['1h']
    m30 = dfs['30m']
    h1['ema50'] = ema(h1['close'],50)
    h1['ema200'] = ema(h1['close'],200)
    m30['ema50'] = ema(m30['close'],50)
    m30['ema200'] = ema(m30['close'],200)
    for tf_df in [h1,m30]:
        tf_df['vwap'] = add_vwap_daily(tf_df)
    bullish_h1 = (h1['ema50'].iloc[-1] > h1['ema200'].iloc[-1]) and (h1['close'].iloc[-1] > h1['vwap'].iloc[-1])
    bullish_m30 = (m30['ema50'].iloc[-1] > m30['ema200'].iloc[-1]) and (m30['close'].iloc[-1] > m30['vwap'].iloc[-1])
    if not (bullish_h1 and bullish_m30):
        return {"signal": None, "reason": "Context not bullish on H1/M30", "time": now.isoformat() if now else None}
    for label in ['1m','3m','5m']:
        df = dfs.get(label)
        if df is None: continue
        if cfg['heikin_ashi']:
            ha = heikin_ashi(df)
            df = df.join(ha, how='left')
            df['use_close'] = df['ha_close']
            df['use_high'] = df['ha_high']
            df['use_low'] = df['ha_low']
        else:
            df['use_close'] = df['close']
            df['use_high'] = df['high']
            df['use_low'] = df['low']
        df['ema9'] = ema(df['use_close'],9)
        df['ema50'] = ema(df['use_close'],50)
        df['rsi'] = rsi(df['use_close'],14)
        df['vwap'] = add_vwap_daily(df)
        df = detect_green_dot(df)
        df['vol_mean10'] = df['volume'].rolling(10).mean()
        df['vol_spike'] = df['volume'] > (df['vol_mean10'] * cfg['volume_spike_mult'])
        last_price = df['use_close'].iloc[-1]
        last_ema50 = df['ema50'].iloc[-1]
        dist_pct = abs(last_price - last_ema50)/last_ema50 if last_ema50 else 0.0
        cond_green_dot = df['green_dot'].iloc[-1]
        cond_rsi = df['rsi'].iloc[-1] > cfg['rsi_entry_level']
        cond_vol = df['vol_spike'].iloc[-1]
        cond_close_above_ema9 = df['use_close'].iloc[-1] > df['ema9'].iloc[-1]
        cond_dist_ok = dist_pct <= cfg['max_distance_from_ema50_pct']
        cond_not_overbought = df['rsi'].iloc[-1] < cfg['rsi_overbought']
        prev_high = df['use_high'].iloc[-2]
        breakout = df['use_close'].iloc[-1] > prev_high
        strong_signal = all([cond_green_dot,cond_rsi,cond_vol,cond_close_above_ema9,cond_dist_ok,cond_not_overbought,breakout])
        weak_signal = all([cond_green_dot,cond_rsi,cond_close_above_ema9,cond_dist_ok,cond_not_overbought,breakout])
        if strong_signal:
            entry_price = df['use_close'].iloc[-1]
            sl = df['use_low'].iloc[-2]
            if sl >= entry_price: sl = entry_price*(1-cfg['sl_pct'])
            tp = entry_price*(1+cfg['tp_pct'])
            return {"signal":"STRONG_LONG","tf":label,"entry":float(entry_price),"sl":float(sl),"tp":float(tp),"reason":"GreenDot + RSI+Volume+Breakout + H1/M30 bullish","time":now.isoformat()}
        elif weak_signal:
            entry_price = df['use_close'].iloc[-1]
            sl = entry_price*(1-cfg['sl_pct'])
            tp = entry_price*(1+cfg['tp_pct'])
            return {"signal":"LONG","tf":label,"entry":float(entry_price),"sl":float(sl),"tp":float(tp),"reason":"GreenDot + RSI + Breakout (no vol spike)","time":now.isoformat()}
    return {"signal":None,"reason":"No entry conditions met","time":now.isoformat()}

# -----------------------------
# MAIN LOOP
# -----------------------------
def main_loop(cfg):
    exchange = init_exchange(cfg)
    usdt_symbols = [s for s in exchange.markets if 'USDT' in s]
    print(f"Exchange loaded. {len(usdt_symbols)} USDT symbols found.")
    try:
        while True:
            t0 = time.time()
            for symbol in usdt_symbols:
                try:
                    res = analyze_pair(exchange, symbol, cfg)
                    now_local = datetime.now(timezone.utc).astimezone().isoformat()
                    if res.get("signal"):
                        print(f"[{now_local}] {symbol} SIGNAL: {res['signal']} | TF: {res.get('tf')} | ENTRY: {res['entry']:.2f} SL: {res['sl']:.2f} TP: {res['tp']:.2f} | {res['reason']}")
                    else:
                        print(f"[{now_local}] {symbol} No signal. Reason: {res['reason']}")
                except Exception as e:
                    print(f"Error analyzing {symbol}: {e}")
            elapsed = time.time() - t0
            time.sleep(max(1, cfg['analysis_interval_sec'] - elapsed))
    except KeyboardInterrupt:
        print("Stopped by user.")

# -----------------------------
# Запуск
# -----------------------------
if __name__ == "__main__":
    main_loop(CONFIG)
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# [2025-10-19T12:44:36.996891+00:00] NMR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:38.270098+00:00] NOT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:39.530933+00:00] OAS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:40.791887+00:00] OKSOL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:42.054716+00:00] OL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:43.282807+00:00] OM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:44.529966+00:00] OMI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:45.792288+00:00] ONDO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:47.024216+00:00] ONE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:48.260239+00:00] ONT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:49.591422+00:00] OP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:50.835229+00:00] ORBS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:52.111136+00:00] ORDI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:53.402267+00:00] PARTI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:54.653707+00:00] PAXG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:55.897748+00:00] PENDLE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:57.167996+00:00] PENGU/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:58.501435+00:00] PEOPLE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:44:59.760239+00:00] PEPE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:01.024014+00:00] PERP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:02.358821+00:00] PHA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:03.688118+00:00] PI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:05.010865+00:00] PIXEL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:06.260397+00:00] PNUT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:07.524087+00:00] POL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:08.795309+00:00] POR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:10.081550+00:00] PRCL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:11.328526+00:00] PROMPT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:12.561673+00:00] PROVE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:13.850190+00:00] PSTAKE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:15.130119+00:00] PYTH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:16.404178+00:00] PYUSD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:17.688257+00:00] QTUM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:18.970286+00:00] RACA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:20.322141+00:00] RAY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:21.567452+00:00] RDNT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:22.834765+00:00] RENDER/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:24.087944+00:00] RESOLV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:25.337441+00:00] RIO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:26.627364+00:00] RON/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:27.956974+00:00] RPL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:29.264707+00:00] RSR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:30.548229+00:00] RSS3/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:31.958431+00:00] RVN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:33.234512+00:00] S/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:34.517602+00:00] SAFE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:35.772041+00:00] SAHARA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:37.056963+00:00] SAND/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:38.326405+00:00] SATS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:39.585280+00:00] SCR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:40.871932+00:00] SD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:42.123442+00:00] SHIB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:43.421931+00:00] SKL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:44.697890+00:00] SKY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:45.977876+00:00] SLERF/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:47.236526+00:00] SLP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:48.651124+00:00] SNT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:49.915850+00:00] SNX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:51.220406+00:00] SONIC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:52.509253+00:00] SOPH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:53.784525+00:00] SPK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:55.044378+00:00] SPURS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:56.321207+00:00] SSV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:57.568684+00:00] STETH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:45:58.855943+00:00] STORJ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:00.250952+00:00] STRK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:01.537921+00:00] STX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:02.834793+00:00] SUI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:04.123530+00:00] SUSHI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:05.371242+00:00] SWEAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:06.639572+00:00] SWFTC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:07.899527+00:00] T/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:09.189727+00:00] THETA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:10.461362+00:00] TIA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:11.748773+00:00] TNSR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:13.013787+00:00] TON/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:14.305375+00:00] TOSHI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:15.572795+00:00] TRA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:16.876018+00:00] TRB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:18.169252+00:00] TRUMP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:19.540763+00:00] TRX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:20.798886+00:00] TURBO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:22.066445+00:00] ULTI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:23.340757+00:00] UMA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:24.638433+00:00] UNI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:25.965175+00:00] USDC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:27.254805+00:00] USDG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:28.553372+00:00] USD1/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:29.829389+00:00] UXLINK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:31.094797+00:00] VELO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:32.390363+00:00] VELODROME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:33.651366+00:00] VINE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:35.066011+00:00] VRA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:36.346946+00:00] W/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:37.650159+00:00] WAXP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:38.926916+00:00] WCT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:40.208221+00:00] WIF/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:41.471180+00:00] WINTOKEN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:42.741624+00:00] WLD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:43.998143+00:00] WOO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:45.233590+00:00] XAUT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:46.489771+00:00] XCH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:47.896143+00:00] XLM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:49.158803+00:00] XPL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:50.646418+00:00] XTZ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:51.918171+00:00] YB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:53.164908+00:00] YFI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:54.423642+00:00] YGG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:55.691901+00:00] ZBCN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:56.984691+00:00] ZENT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:58.253666+00:00] ZETA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:46:59.509037+00:00] ZEUS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:00.788351+00:00] ZIL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:02.085855+00:00] ZK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:03.348231+00:00] ZKJ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:04.583691+00:00] ZORA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:05.862994+00:00] ZRO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:07.103283+00:00] ZRX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:08.424966+00:00] BTC/USDT:USDT-251024 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:09.724111+00:00] BTC/USDT:USDT-251031 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:11.009546+00:00] BTC/USDT:USDT-251128 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:12.282742+00:00] BTC/USDT:USDT-251226 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:13.579147+00:00] BTC/USDT:USDT-260327 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:14.963603+00:00] BTC/USDT:USDT-260626 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:16.247776+00:00] ETH/USDT:USDT-251024 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:17.562177+00:00] ETH/USDT:USDT-251031 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:18.812344+00:00] ETH/USDT:USDT-251226 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:20.076241+00:00] ETH/USDT:USDT-260327 No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:21.325660+00:00] BTC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:22.537854+00:00] ETH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:23.802909+00:00] OKB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:25.062752+00:00] SOL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:26.295637+00:00] DOGE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:27.535802+00:00] XRP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:28.784523+00:00] BCH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:30.091455+00:00] PUMP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:31.368615+00:00] WLFI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:32.627627+00:00] LINEA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:33.862365+00:00] 0G/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:35.188674+00:00] 1INCH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:36.452100+00:00] 2Z/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:37.693793+00:00] A/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:38.923470+00:00] AAVE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:40.147610+00:00] ACE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:41.398044+00:00] ACH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:42.651755+00:00] ACT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:43.905093+00:00] ADA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:45.169081+00:00] AERO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:46.424489+00:00] AEVO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:47.707916+00:00] AGLD/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:48.995373+00:00] AI16Z/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:50.511230+00:00] AIXBT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:51.769990+00:00] ALGO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:53.025589+00:00] ANIME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:54.262417+00:00] APE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:55.614287+00:00] API3/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:56.870278+00:00] APT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:58.167202+00:00] AR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:47:59.435728+00:00] ARB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:00.705454+00:00] ARKM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:01.966971+00:00] ASTER/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:03.201137+00:00] ATH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:04.459742+00:00] ATOM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:05.732817+00:00] AUCTION/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:06.969475+00:00] AVAX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:08.234672+00:00] AVAAI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:09.527547+00:00] AVNT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:10.815716+00:00] AXS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:12.092043+00:00] BABY/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:13.352275+00:00] BAND/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:14.599682+00:00] BARD/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:15.865552+00:00] BAT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:17.118647+00:00] BERA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:18.365384+00:00] BICO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:19.593613+00:00] BIGTIME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:20.859888+00:00] BIO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:22.149607+00:00] BLUR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:23.498332+00:00] BNB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:24.802453+00:00] BNT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:26.055334+00:00] BOME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:27.314330+00:00] BONK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:28.567746+00:00] BRETT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:29.831891+00:00] CAT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:31.103028+00:00] CATI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:32.410196+00:00] CELO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:33.685187+00:00] CETUS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:34.958877+00:00] CFX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:36.230998+00:00] CHZ/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:37.481533+00:00] COAI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:38.759493+00:00] COMP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:40.026046+00:00] COOKIE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:41.303204+00:00] CORE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:42.612235+00:00] CRO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:43.927751+00:00] CRV/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:45.208530+00:00] CTC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:46.454603+00:00] CVC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:47.738215+00:00] CVX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:48.992981+00:00] DEGEN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:50.252780+00:00] DOGS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:51.510556+00:00] DOOD/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:52.765222+00:00] DOT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:54.017892+00:00] DYDX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:55.244483+00:00] EDEN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:56.517018+00:00] EGLD/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:57.787400+00:00] EIGEN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:48:59.032378+00:00] ENA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:00.325692+00:00] ENJ/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:01.573990+00:00] ENS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:02.819210+00:00] ETC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:04.098982+00:00] ETHW/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:05.457156+00:00] ETHFI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:06.753073+00:00] FARTCOIN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:08.011478+00:00] FIL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:09.318306+00:00] FLM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:10.586265+00:00] FLOKI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:11.859242+00:00] FLOW/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:13.101020+00:00] FXS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:14.354249+00:00] GALA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:15.600316+00:00] GAS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:16.859066+00:00] GLM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:18.101341+00:00] GMT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:19.372098+00:00] GMX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:20.659500+00:00] GOAT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:21.913805+00:00] GPS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:23.168692+00:00] GRASS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:24.429648+00:00] GRT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:25.841715+00:00] H/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:27.090030+00:00] HBAR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:28.341546+00:00] HMSTR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:29.617021+00:00] HOME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:30.890029+00:00] HUMA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:32.170231+00:00] HYPE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:33.428890+00:00] ICP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:34.680743+00:00] ICX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:35.923811+00:00] IMX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:37.185159+00:00] INIT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:38.470174+00:00] INJ/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:39.743302+00:00] IOST/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:41.109632+00:00] IOTA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:42.365576+00:00] IP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:43.673173+00:00] JELLYJELLY/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:44.933782+00:00] JOE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:46.187191+00:00] JTO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:47.584421+00:00] JUP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:48.862877+00:00] KAITO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:50.165586+00:00] KGEN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:51.434048+00:00] KMNO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:52.680273+00:00] KSM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:53.917936+00:00] LA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:55.200560+00:00] LAUNCHCOIN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:56.476509+00:00] LAYER/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:57.927376+00:00] LDO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:49:59.261567+00:00] LINK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:00.544514+00:00] LPT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:01.815123+00:00] LQTY/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:03.137854+00:00] LRC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:04.440976+00:00] LTC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:05.714121+00:00] LUNA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:07.202630+00:00] MAGIC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:08.491543+00:00] MANA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:09.783609+00:00] MASK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:11.045893+00:00] ME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:12.299954+00:00] MEME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:13.612028+00:00] MERL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:14.879411+00:00] METIS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:16.120969+00:00] MET/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:17.379757+00:00] MEW/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:18.798306+00:00] MINA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:20.122186+00:00] MOG/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:21.386983+00:00] MON/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:22.664975+00:00] MOODENG/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:23.920244+00:00] MORPHO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:25.183304+00:00] MOVE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:26.435260+00:00] MUBARAK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:27.706752+00:00] NEAR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:28.935769+00:00] NEIRO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:30.234469+00:00] NEO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:31.494960+00:00] NEWT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:32.756244+00:00] NMR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:34.030020+00:00] NOT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:35.296035+00:00] NXPC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:36.575944+00:00] OL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:37.820663+00:00] OM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:39.104592+00:00] ONDO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:40.356719+00:00] ONE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:41.639623+00:00] ONT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:42.919083+00:00] OP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:44.163756+00:00] ORDI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:45.418858+00:00] ORDER/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:46.695074+00:00] PARTI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:47.978896+00:00] PENGU/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:49.232979+00:00] PENDLE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:50.502509+00:00] PEOPLE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:51.808221+00:00] PEPE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:53.124250+00:00] PERP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:54.399535+00:00] PI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:55.671956+00:00] PLUME/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:56.914943+00:00] PNUT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:58.191988+00:00] POL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:50:59.445038+00:00] POPCAT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:00.917209+00:00] PRCL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:02.239389+00:00] PROMPT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:03.456693+00:00] PROVE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:04.709803+00:00] PYTH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:05.994932+00:00] QTUM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:07.246199+00:00] RAY/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:08.519706+00:00] RENDER/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:09.759420+00:00] RESOLV/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:11.168022+00:00] RSR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:12.443009+00:00] RVN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:13.764471+00:00] S/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:15.013880+00:00] SAHARA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:16.365242+00:00] SAND/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:17.698865+00:00] SATS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:18.987802+00:00] SCR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:20.240318+00:00] SHELL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:21.506887+00:00] SHIB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:22.781512+00:00] SIGN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:24.075219+00:00] SKY/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:25.341496+00:00] SLP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:26.681176+00:00] SNX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:27.955260+00:00] SOLV/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:29.265479+00:00] SONIC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:30.556040+00:00] SOON/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:31.915858+00:00] SOPH/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:33.410243+00:00] SPK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:34.662022+00:00] SPX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:35.917041+00:00] SSV/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:37.191773+00:00] STORJ/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:38.446719+00:00] STRK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:39.728382+00:00] STX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:41.028460+00:00] SUI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:42.324145+00:00] SUSHI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:43.629559+00:00] SYRUP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:44.923165+00:00] T/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:46.197691+00:00] TAO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:47.496748+00:00] THETA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:48.801968+00:00] TIA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:50.072645+00:00] TNSR/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:51.331880+00:00] TON/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:52.687117+00:00] TRB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:54.083273+00:00] TREE/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:55.364034+00:00] TRUMP/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:56.692534+00:00] TRX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:57.959586+00:00] TURBO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:51:59.291002+00:00] UMA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:00.587979+00:00] UNI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:01.887045+00:00] USDC/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:03.191280+00:00] USELESS/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:04.549709+00:00] VANA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:05.897549+00:00] VIRTUAL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:07.166938+00:00] W/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:08.454572+00:00] WAL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:09.723759+00:00] WCT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:11.003235+00:00] WIF/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:12.291802+00:00] WLD/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:13.539518+00:00] WOO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:14.798166+00:00] XAN/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:16.049988+00:00] XAUT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:17.367016+00:00] XLM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:18.639167+00:00] XPL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:19.900214+00:00] XTZ/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:21.196263+00:00] YB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:22.459491+00:00] YFI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:23.773167+00:00] YGG/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:25.020103+00:00] ZBT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:26.302159+00:00] ZENT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:27.565984+00:00] ZETA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:28.860776+00:00] ZIL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:30.118893+00:00] ZK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:31.418350+00:00] ZORA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:32.687326+00:00] ZRO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:33.929318+00:00] ZRX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:36.236013+00:00] USDT/SGD No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:37.513058+00:00] USDT/AUD No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:38.789926+00:00] USDT/AED No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:40.067110+00:00] USDT/BRL No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:41.367805+00:00] USDT/EUR No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:42.633430+00:00] USDT/TRY No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:43.938072+00:00] USDT/USD No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:45.219491+00:00] BTC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:46.497848+00:00] ETH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:47.759724+00:00] OKB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:49.080696+00:00] SOL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:50.319994+00:00] DOGE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:51.618883+00:00] XRP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:52.978988+00:00] BCH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:54.217397+00:00] PUMP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:55.492620+00:00] WLFI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:56.774574+00:00] LINEA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:58.026292+00:00] 1INCH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:52:59.271955+00:00] A/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:00.527206+00:00] AAVE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:01.810784+00:00] ACA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:03.085535+00:00] ACE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:04.414053+00:00] ACH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:05.666348+00:00] ACT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:06.921779+00:00] ADA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:08.223406+00:00] AERGO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:09.471706+00:00] AEVO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:10.716869+00:00] AGLD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:11.990657+00:00] AIDOGE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:13.273443+00:00] AIXBT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:14.672207+00:00] ALGO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:16.032169+00:00] ALPHA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:17.295566+00:00] ANIME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:18.555014+00:00] APE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:19.808065+00:00] API3/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:21.097373+00:00] APT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:22.382260+00:00] AR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:23.646170+00:00] ARB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:24.945009+00:00] ARG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:26.235993+00:00] ARKM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:27.529549+00:00] ASP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:28.779376+00:00] ASTR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:30.015596+00:00] ASTER/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:31.262355+00:00] ATH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:32.540343+00:00] ATOM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:33.812061+00:00] AUCTION/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:35.167713+00:00] AVAX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:36.437407+00:00] AVNT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:37.707558+00:00] AXS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:39.006755+00:00] BABYDOGE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:40.271803+00:00] BABY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:41.696860+00:00] BADGER/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:42.942236+00:00] BAL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:44.198688+00:00] BAND/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:45.568215+00:00] BANANA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:46.881743+00:00] BARD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:48.142550+00:00] BAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:49.384348+00:00] BERA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:50.651668+00:00] BETH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:51.944439+00:00] BICO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:53.177386+00:00] BIGTIME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:54.421962+00:00] BIO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:55.696648+00:00] BLUR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:56.950034+00:00] BNB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:58.210785+00:00] BNT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:53:59.540795+00:00] BOME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:00.803125+00:00] BONK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:02.069659+00:00] CATI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:03.350857+00:00] CAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:04.642373+00:00] CELO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:05.982394+00:00] CELR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:07.271093+00:00] CETUS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:08.733960+00:00] CFG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:10.104315+00:00] CFX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:11.378074+00:00] CHZ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:12.632997+00:00] CITY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:14.030468+00:00] CLV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:15.299711+00:00] COMP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:16.576010+00:00] CORE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:17.872602+00:00] CRO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:19.115716+00:00] CRV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:20.385628+00:00] CSPR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:21.640309+00:00] CTC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:22.928997+00:00] CVC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:24.257172+00:00] CVX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:25.528948+00:00] CXT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:26.785438+00:00] DAI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:28.040563+00:00] DAO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:29.300883+00:00] DEGEN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:30.549994+00:00] DEP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:31.827243+00:00] DGB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:33.079493+00:00] DOGS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:34.313353+00:00] DOOD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:35.569575+00:00] DORA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:36.848780+00:00] DOT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:38.134050+00:00] DUCK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:39.362363+00:00] DYDX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:40.631550+00:00] EGLD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:41.874475+00:00] EIGEN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:43.275559+00:00] ELF/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:44.549647+00:00] ELON/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:45.802723+00:00] ENA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:47.060000+00:00] ENJ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:48.373193+00:00] ENS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:49.717769+00:00] ETC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:51.072111+00:00] ETHW/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:52.353240+00:00] ETHFI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:53.674059+00:00] FET/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:54.934309+00:00] FIL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:56.201029+00:00] FLM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:57.457387+00:00] FLOW/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:54:58.729288+00:00] FLOKI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:00.036015+00:00] FLR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:01.354485+00:00] FLUID/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:02.722979+00:00] FOXY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:04.028876+00:00] FXS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:05.327230+00:00] G/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:06.631617+00:00] GALA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:08.180613+00:00] GALFT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:09.422439+00:00] GAS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:10.710785+00:00] GEAR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:11.969428+00:00] GHST/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T12:55:13.304653+00:00] GLM/USDT No signal. Reason: Context not bullish on H1/M30
# ...
# [2025-10-19T14:29:47.400461+00:00] XAUT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:48.798092+00:00] XLM/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:50.059906+00:00] XPL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:51.317592+00:00] XTZ/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:52.653129+00:00] YB/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:53.929481+00:00] YFI/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:55.353968+00:00] YGG/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:56.617601+00:00] ZBT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:57.886467+00:00] ZENT/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:29:59.151937+00:00] ZETA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:00.433493+00:00] ZIL/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:01.855328+00:00] ZK/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:03.226696+00:00] ZORA/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:04.635632+00:00] ZRO/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:05.978550+00:00] ZRX/USDT:USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:08.283002+00:00] USDT/SGD No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:09.561320+00:00] USDT/AUD No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:10.870367+00:00] USDT/AED No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:12.133193+00:00] USDT/BRL No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:13.499422+00:00] USDT/EUR No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:14.810181+00:00] USDT/TRY No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:16.298778+00:00] USDT/USD No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:17.659417+00:00] BTC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:19.018287+00:00] ETH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:20.302121+00:00] OKB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:21.628457+00:00] SOL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:22.913349+00:00] DOGE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:24.188402+00:00] XRP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:25.463822+00:00] BCH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:26.879811+00:00] PUMP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:28.193927+00:00] WLFI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:29.457286+00:00] LINEA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:30.780043+00:00] 1INCH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:32.077024+00:00] A/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:33.350771+00:00] AAVE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:34.603210+00:00] ACA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:35.932384+00:00] ACE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:37.293517+00:00] ACH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:38.657650+00:00] ACT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:39.988512+00:00] ADA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:41.273411+00:00] AERGO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:42.562998+00:00] AEVO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:43.904120+00:00] AGLD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:45.145143+00:00] AIDOGE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:46.546184+00:00] AIXBT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:47.805471+00:00] ALGO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:49.090731+00:00] ALPHA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:50.357116+00:00] ANIME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:51.636154+00:00] APE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:52.940326+00:00] API3/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:54.214158+00:00] APT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:55.490073+00:00] AR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:56.839992+00:00] ARB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:58.146654+00:00] ARG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:30:59.439432+00:00] ARKM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:00.682120+00:00] ASP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:02.023599+00:00] ASTR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:03.280194+00:00] ASTER/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:04.631779+00:00] ATH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:05.912878+00:00] ATOM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:07.171425+00:00] AUCTION/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:08.424450+00:00] AVAX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:09.685084+00:00] AVNT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:10.972438+00:00] AXS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:12.238431+00:00] BABYDOGE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:13.579116+00:00] BABY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:14.876568+00:00] BADGER/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:16.175665+00:00] BAL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:17.434008+00:00] BAND/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:18.889768+00:00] BANANA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:20.180945+00:00] BARD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:21.451874+00:00] BAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:22.693666+00:00] BERA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:23.981925+00:00] BETH/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:25.324161+00:00] BICO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:26.658354+00:00] BIGTIME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:27.929612+00:00] BIO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:29.202910+00:00] BLUR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:30.501075+00:00] BNB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:31.874526+00:00] BNT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:33.191426+00:00] BOME/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:34.458306+00:00] BONK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:35.735105+00:00] CATI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:37.128599+00:00] CAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:38.426878+00:00] CELO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:39.917601+00:00] CELR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:41.188758+00:00] CETUS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:42.483102+00:00] CFG/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:43.749520+00:00] CFX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:45.054240+00:00] CHZ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:46.307710+00:00] CITY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:47.582473+00:00] CLV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:48.878208+00:00] COMP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:50.132735+00:00] CORE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:51.450790+00:00] CRO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:52.734057+00:00] CRV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:53.987225+00:00] CSPR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:55.271207+00:00] CTC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:56.551256+00:00] CVC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:57.825070+00:00] CVX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:31:59.153031+00:00] CXT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:00.468473+00:00] DAI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:01.754233+00:00] DAO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:03.028949+00:00] DEGEN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:04.322719+00:00] DEP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:05.600062+00:00] DGB/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:06.888698+00:00] DOGS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:08.183766+00:00] DOOD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:09.443009+00:00] DORA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:10.699246+00:00] DOT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:12.012753+00:00] DUCK/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:13.377418+00:00] DYDX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:14.634351+00:00] EGLD/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:15.902328+00:00] EIGEN/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:17.195015+00:00] ELF/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:18.445104+00:00] ELON/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:19.777075+00:00] ENA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:21.044044+00:00] ENJ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:22.341460+00:00] ENS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:23.652002+00:00] ETC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:24.915352+00:00] ETHW/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:26.194528+00:00] ETHFI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:27.550615+00:00] FET/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:28.929726+00:00] FIL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:30.234086+00:00] FLM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:31.519987+00:00] FLOW/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:32.794792+00:00] FLOKI/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:34.083399+00:00] FLR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:35.383987+00:00] FLUID/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:36.667781+00:00] FOXY/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:37.935093+00:00] FXS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:39.216061+00:00] G/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:40.484146+00:00] GALA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:41.777909+00:00] GALFT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:43.067478+00:00] GAS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:44.379245+00:00] GEAR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:45.644811+00:00] GHST/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:46.927174+00:00] GLM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:48.212143+00:00] GMT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:49.503429+00:00] GMX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:50.775307+00:00] GOAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:52.035497+00:00] GODS/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:53.332451+00:00] GRT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:54.659238+00:00] HBAR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:55.953000+00:00] HMSTR/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:57.279847+00:00] HUMA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:58.626106+00:00] ICE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:32:59.903726+00:00] ICP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:01.176027+00:00] ICX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:02.475537+00:00] ID/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:03.750241+00:00] ILV/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:05.043735+00:00] IMX/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:06.308503+00:00] INJ/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:07.583812+00:00] IOST/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:08.864682+00:00] IOTA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:10.145630+00:00] IP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:11.561407+00:00] J/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:12.831210+00:00] JITOSOL/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:14.105231+00:00] JOE/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:15.387455+00:00] JTO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:16.679150+00:00] JUP/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:17.950149+00:00] KAIA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:19.205354+00:00] KAITO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:20.485897+00:00] KDA/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:21.816858+00:00] KMNO/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:23.103343+00:00] KNC/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:24.380266+00:00] KSM/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:25.640331+00:00] LAT/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:26.921931+00:00] LAYER/USDT No signal. Reason: Context not bullish on H1/M30
# [2025-10-19T14:33:28.184202+00:00] LDO/USDT No signal. Reason: Context not bullish on H1/M30
