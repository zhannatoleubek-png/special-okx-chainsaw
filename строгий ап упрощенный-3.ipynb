# %% [markdown]
# <a href="https://colab.research.google.com/github/zhannatoleubek-png/special-okx-chainsaw/blob/main/%D1%81%D1%82%D1%80%D0%BE%D0%B3%D0%B8%D0%B9%20%D0%B0%D0%BF%20%D1%83%D0%BF%D1%80%D0%BE%D1%89%D0%B5%D0%BD%D0%BD%D1%8B%D0%B9-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ✅ Colab-ready OKX Scanner with Enhanced Trend Detection

# !pip install --quiet ccxt pandas numpy requests ta

import time
import datetime as dt
import requests
import pandas as pd
import numpy as np
import ccxt
from ta.momentum import RSIIndicator
from ta.volume import OnBalanceVolumeIndicator
from ta.trend import EMAIndicator

# ---------------- CONFIG ----------------
CONFIG = {
    "telegram_bot_token": "YOUR_TELEGRAM_BOT_TOKEN",
    "telegram_chat_id": "YOUR_CHAT_ID",
    "scan_interval": 60,
    "min_volume_usdt": 100000,
}

# ---------------- TELEGRAM ----------------
def send_telegram(msg: str):
    try:
        requests.post(
            f"https://api.telegram.org/bot{CONFIG['telegram_bot_token']}/sendMessage",
            data={"chat_id": CONFIG["telegram_chat_id"], "text": msg, "parse_mode": "Markdown"}
        )
    except Exception as e:
        print(f"Telegram error: {e}")

# ---------------- EXCHANGE ----------------
exchange = ccxt.okx({"enableRateLimit": True})

def safe_fetch_ohlcv(symbol, timeframe='15m', limit=200):
    try:
        return exchange.fetch_ohlcv(symbol, timeframe=timeframe, limit=limit)
    except Exception:
        return None

# ---------------- INDICATOR BLOCK ----------------
def calc_indicators(df):
    df["rsi"] = RSIIndicator(df["close"], 14).rsi()
    df["ema20"] = EMAIndicator(df["close"], 20).ema_indicator()
    df["ema50"] = EMAIndicator(df["close"], 50).ema_indicator()
    df["ema200"] = EMAIndicator(df["close"], 200).ema_indicator()
    df["obv"] = OnBalanceVolumeIndicator(df["close"], df["vol"]).on_balance_volume()
    return df

# ---------------- ENHANCED CONTEXT ANALYSIS ----------------
def context_analysis(symbol):
    """Context (1H–4H): adaptive trend detection with more tolerance"""
    for tf in ['1h', '4h']:
        ohlcv = safe_fetch_ohlcv(symbol, tf, limit=200)
        if not ohlcv:
            continue
        df = pd.DataFrame(ohlcv, columns=['ts','open','high','low','close','vol']).astype(float)
        ema50 = EMAIndicator(df['close'], 50).ema_indicator()
        ema200 = EMAIndicator(df['close'], 200).ema_indicator()
        last = df.iloc[-2]

        ema_slope = ema50.iloc[-2] - ema50.iloc[-7]
        price = last['close']
        ema_ratio = (ema50.iloc[-2] / ema200.iloc[-2]) - 1  # насколько EMA50 выше/ниже EMA200

        # 🔧 Более гибкий фильтр тренда:
        if (ema_ratio > 0.002 or ema_slope > 0):   # 0.2% и выше — ап
            return "up"
        elif (ema_ratio < -0.002 or ema_slope < 0):  # 0.2% и ниже — даун
            return "down"

    return "sideways"

# ---------------- SIGNAL SCANNER ----------------
def analyze_symbol(symbol):
    ohlcv = safe_fetch_ohlcv(symbol, '15m')
    if not ohlcv:
        return None

    df = pd.DataFrame(ohlcv, columns=['ts','open','high','low','close','vol']).astype(float)
    df = calc_indicators(df)
    last = df.iloc[-2]

    context = context_analysis(symbol)
    if context == "sideways":
        print(f"⛔ {symbol}: контекст sideways — пропуск")
        return None

    signal = None
    if context == "up":
        if last["rsi"] < 40 and last["close"] > last["ema50"] and last["ema50"] > last["ema200"]:
            signal = f"🟢 LONG {symbol} | RSI={last['rsi']:.1f}"
    elif context == "down":
        if last["rsi"] > 60 and last["close"] < last["ema50"] and last["ema50"] < last["ema200"]:
            signal = f"🔴 SHORT {symbol} | RSI={last['rsi']:.1f}"

    if signal:
        print(f"✅ {signal}")
        send_telegram(signal)
    else:
        print(f"⛔ {symbol}: нет сигнала")

# ---------------- SCANNER MAIN LOOP ----------------
def run_scanner():
    print("🚀 Scanner started...")
    markets = exchange.load_markets()
    usdt_pairs = [s for s in markets if "/USDT" in s]
    print(f"✅ Found {len(usdt_pairs)} liquid symbols (>100000 USDT 24h volume)")

    while True:
        for symbol in usdt_pairs:
            try:
                ticker = exchange.fetch_ticker(symbol)
                if ticker['quoteVolume'] and ticker['quoteVolume'] > CONFIG['min_volume_usdt']:
                    print(f"🔍 {symbol}")
                    analyze_symbol(symbol)
                else:
                    print(f"⏩ {symbol}: low volume")
            except Exception as e:
                print(f"⚠️ Error {symbol}: {e}")
                continue

        print(f"⏱ Waiting {CONFIG['scan_interval']}s before next scan...\n")
        time.sleep(CONFIG["scan_interval"])

# ---------------- START ----------------
run_scanner()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
# ⏩ DOGE/USDT:USDT: low volume
# ⏩ XRP/USDT:USDT: low volume
# ⏩ BCH/USDT:USDT: low volume
# ⏩ PUMP/USDT:USDT: low volume
# ⏩ WLFI/USDT:USDT: low volume
# ⏩ LINEA/USDT:USDT: low volume
# ⏩ 0G/USDT:USDT: low volume
# ⏩ 1INCH/USDT:USDT: low volume
# ⏩ 2Z/USDT:USDT: low volume
# ⏩ A/USDT:USDT: low volume
# ⏩ AAVE/USDT:USDT: low volume
# ⏩ ACE/USDT:USDT: low volume
# ⏩ ACH/USDT:USDT: low volume
# ⏩ ACT/USDT:USDT: low volume
# ⏩ ADA/USDT:USDT: low volume
# ⏩ AERO/USDT:USDT: low volume
# ⏩ AEVO/USDT:USDT: low volume
# ⏩ AGLD/USDT:USDT: low volume
# ⏩ AI16Z/USDT:USDT: low volume
# ⏩ AIXBT/USDT:USDT: low volume
# ⏩ ALGO/USDT:USDT: low volume
# ⏩ ANIME/USDT:USDT: low volume
# ⏩ APE/USDT:USDT: low volume
# ⏩ API3/USDT:USDT: low volume
# ⏩ APT/USDT:USDT: low volume
# ⏩ AR/USDT:USDT: low volume
# ⏩ ARB/USDT:USDT: low volume
# ⏩ ARKM/USDT:USDT: low volume
# ⏩ ASTER/USDT:USDT: low volume
# ⏩ ATH/USDT:USDT: low volume
# ⏩ ATOM/USDT:USDT: low volume
# ⏩ AUCTION/USDT:USDT: low volume
# ⏩ AVAX/USDT:USDT: low volume
# ⏩ AVAAI/USDT:USDT: low volume
# ⏩ AVNT/USDT:USDT: low volume
# ⏩ AXS/USDT:USDT: low volume
# ⏩ BABY/USDT:USDT: low volume
# ⏩ BAND/USDT:USDT: low volume
#
# 🔍 BTC/USDT
# ⛔ BTC/USDT: нет сигнала
# 🔍 ETH/USDT
# ⛔ ETH/USDT: нет сигнала
# 🔍 OKB/USDT
# ⛔ OKB/USDT: нет сигнала
# 🔍 SOL/USDT
# ⛔ SOL/USDT: нет сигнала
# 🔍 DOGE/USDT
# ⛔ DOGE/USDT: нет сигнала
# 🔍 XRP/USDT
# ⛔ XRP/USDT: нет сигнала
# 🔍 BCH/USDT
# ⛔ BCH/USDT: нет сигнала
# 🔍 PUMP/USDT
# ⛔ PUMP/USDT: нет сигнала
# 🔍 WLFI/USDT
# ⛔ WLFI/USDT: нет сигнала
# 🔍 LINEA/USDT
# ⛔ LINEA/USDT: нет сигнала
# 🔍 1INCH/USDT
# ⛔ 1INCH/USDT: нет сигнала
# 🔍 A/USDT
# ⛔ A/USDT: нет сигнала
# 🔍 AAVE/USDT
# ⛔ AAVE/USDT: нет сигнала
# ⏩ ACA/USDT: low volume
# 🔍 ACE/USDT
# ⛔ ACE/USDT: нет сигнала
# 🔍 ACH/USDT
# ⛔ ACH/USDT: нет сигнала
# 🔍 ACT/USDT
# ⛔ ACT/USDT: нет сигнала
# 🔍 ADA/USDT
# ⛔ ADA/USDT: нет сигнала
# 🔍 AERGO/USDT
# ⛔ AERGO/USDT: нет сигнала
# 🔍 AEVO/USDT
# ⛔ AEVO/USDT: нет сигнала
# 🔍 AGLD/USDT
# ⛔ AGLD/USDT: нет сигнала
# 🔍 AIDOGE/USDT
# ⛔ AIDOGE/USDT: нет сигнала
# 🔍 AIXBT/USDT
# ⛔ AIXBT/USDT: нет сигнала
# 🔍 ALGO/USDT
# ⛔ ALGO/USDT: нет сигнала
# 🔍 ALPHA/USDT
# ⛔ ALPHA/USDT: нет сигнала
# 🔍 ANIME/USDT
# ⛔ ANIME/USDT: нет сигнала
# 🔍 APE/USDT
# ⛔ APE/USDT: нет сигнала
# 🔍 API3/USDT
# ⛔ API3/USDT: нет сигнала
# 🔍 APT/USDT
# ⛔ APT/USDT: нет сигнала
# 🔍 AR/USDT
# ⛔ AR/USDT: нет сигнала
# 🔍 ARB/USDT
# ⛔ ARB/USDT: нет сигнала
# ⏩ ARG/USDT: low volume
# 🔍 ARKM/USDT
# ⛔ ARKM/USDT: нет сигнала
# 🔍 ASP/USDT
# ⛔ ASP/USDT: нет сигнала
# 🔍 ASTR/USDT
# ⛔ ASTR/USDT: нет сигнала
# 🔍 ASTER/USDT
# ⛔ ASTER/USDT: контекст sideways — пропуск
# 🔍 ATH/USDT
# ⛔ ATH/USDT: нет сигнала
# 🔍 ATOM/USDT
# ⛔ ATOM/USDT: нет сигнала
# 🔍 AUCTION/USDT
# ⛔ AUCTION/USDT: нет сигнала
# 🔍 AVAX/USDT
# ⛔ AVAX/USDT: нет сигнала
# 🔍 AVNT/USDT
# ⛔ AVNT/USDT: нет сигнала
# 🔍 AXS/USDT
# ⛔ AXS/USDT: нет сигнала
# 🔍 BABYDOGE/USDT
# ⛔ BABYDOGE/USDT: нет сигнала
# 🔍 BABY/USDT
# ⛔ BABY/USDT: нет сигнала
# 🔍 BADGER/USDT
# ⛔ BADGER/USDT: нет сигнала
# ⏩ BAL/USDT: low volume
# ⏩ BAND/USDT: low volume
# 🔍 BANANA/USDT
# ⛔ BANANA/USDT: нет сигнала
# 🔍 BARD/USDT
# ⛔ BARD/USDT: нет сигнала
# 🔍 BAT/USDT
# ⛔ BAT/USDT: нет сигнала
# 🔍 BERA/USDT
# ⛔ BERA/USDT: нет сигнала
# 🔍 BETH/USDT
# ⛔ BETH/USDT: нет сигнала
# ⏩ BICO/USDT: low volume
# 🔍 BIGTIME/USDT
# ⛔ BIGTIME/USDT: нет сигнала
# 🔍 BIO/USDT
# ⛔ BIO/USDT: нет сигнала
# 🔍 BLUR/USDT
# ⛔ BLUR/USDT: нет сигнала
# 🔍 BNB/USDT
# ⛔ BNB/USDT: нет сигнала
# ⏩ BNT/USDT: low volume
# 🔍 BOME/USDT
# ⛔ BOME/USDT: нет сигнала
# 🔍 BONK/USDT
# ⛔ BONK/USDT: нет сигнала
# 🔍 CATI/USDT
# ⛔ CATI/USDT: нет сигнала
# 🔍 CAT/USDT
# ⛔ CAT/USDT: нет сигнала
# 🔍 CELO/USDT
# ⛔ CELO/USDT: нет сигнала
# ⏩ CELR/USDT: low volume
# 🔍 CETUS/USDT
# ⛔ CETUS/USDT: нет сигнала
# 🔍 CFG/USDT
# ⛔ CFG/USDT: нет сигнала
# 🔍 CFX/USDT
# ⛔ CFX/USDT: нет сигнала
# 🔍 CHZ/USDT
# ⛔ CHZ/USDT: нет сигнала
# ⏩ CITY/USDT: low volume
# 🔍 CLV/USDT
# ⛔ CLV/USDT: нет сигнала
# 🔍 COMP/USDT
# ⛔ COMP/USDT: нет сигнала
# 🔍 CORE/USDT
# ⛔ CORE/USDT: нет сигнала
# 🔍 CRO/USDT
# ⛔ CRO/USDT: нет сигнала
# 🔍 CRV/USDT
# ⛔ CRV/USDT: нет сигнала
# 🔍 CSPR/USDT
# ⛔ CSPR/USDT: нет сигнала
# 🔍 CTC/USDT
# ⛔ CTC/USDT: нет сигнала
# 🔍 CVC/USDT
# ⛔ CVC/USDT: нет сигнала
# 🔍 CVX/USDT
# ⛔ CVX/USDT: нет сигнала
# 🔍 CXT/USDT
# ⛔ CXT/USDT: нет сигнала
# 🔍 DAI/USDT
# ⛔ DAI/USDT: нет сигнала
# ⏩ DAO/USDT: low volume
# 🔍 DEGEN/USDT
# ⛔ DEGEN/USDT: нет сигнала
# ⏩ DEP/USDT: low volume
# ⏩ DGB/USDT: low volume
# 🔍 DOGS/USDT
# ⛔ DOGS/USDT: нет сигнала
# 🔍 DOOD/USDT
# ⛔ DOOD/USDT: контекст sideways — пропуск
# ⏩ DORA/USDT: low volume
# 🔍 DOT/USDT
# ⛔ DOT/USDT: нет сигнала
# 🔍 DUCK/USDT
# ⛔ DUCK/USDT: нет сигнала
# 🔍 DYDX/USDT
# ⛔ DYDX/USDT: нет сигнала
# ⏩ EGLD/USDT: low volume
# 🔍 EIGEN/USDT
# ⛔ EIGEN/USDT: нет сигнала
# ⏩ ELF/USDT: low volume
# ⏩ ELON/USDT: low volume
# 🔍 ENA/USDT
# ⛔ ENA/USDT: нет сигнала
# ⏩ ENJ/USDT: low volume
# 🔍 ENS/USDT
# ⛔ ENS/USDT: нет сигнала
# 🔍 ETC/USDT
# ⛔ ETC/USDT: нет сигнала
# 🔍 ETHW/USDT
# ⛔ ETHW/USDT: нет сигнала
# 🔍 ETHFI/USDT
# ⛔ ETHFI/USDT: нет сигнала
# 🔍 FET/USDT
# ⛔ FET/USDT: нет сигнала
# 🔍 FIL/USDT
# ⛔ FIL/USDT: нет сигнала
# 🔍 FLM/USDT
# ⛔ FLM/USDT: нет сигнала
# 🔍 FLOW/USDT
# ⛔ FLOW/USDT: нет сигнала
# 🔍 FLOKI/USDT
# ⛔ FLOKI/USDT: нет сигнала
# 🔍 FLR/USDT
# ⛔ FLR/USDT: нет сигнала
# 🔍 FLUID/USDT
# ⛔ FLUID/USDT: нет сигнала
# ⏩ FOXY/USDT: low volume
# ⏩ FXS/USDT: low volume
# ⏩ G/USDT: low volume
# 🔍 GALA/USDT
# ⛔ GALA/USDT: нет сигнала
# ⏩ GALFT/USDT: low volume
# 🔍 GAS/USDT
# ⛔ GAS/USDT: нет сигнала
# ⏩ GEAR/USDT: low volume
# ⏩ GHST/USDT: low volume
# 🔍 GLM/USDT
# ⛔ GLM/USDT: нет сигнала
# 🔍 GMT/USDT
# ⛔ GMT/USDT: нет сигнала
# 🔍 GMX/USDT
# ⛔ GMX/USDT: нет сигнала
# 🔍 GOAT/USDT
# ⛔ GOAT/USDT: нет сигнала
# 🔍 GODS/USDT
# ⛔ GODS/USDT: нет сигнала
# 🔍 GRT/USDT
# ⛔ GRT/USDT: нет сигнала
# 🔍 HBAR/USDT
# ⛔ HBAR/USDT: нет сигнала
# 🔍 HMSTR/USDT
# ⛔ HMSTR/USDT: нет сигнала
# 🔍 HUMA/USDT
# ⛔ HUMA/USDT: нет сигнала
# 🔍 ICE/USDT
# ⛔ ICE/USDT: нет сигнала
# 🔍 ICP/USDT
# ⛔ ICP/USDT: нет сигнала
# ⏩ ICX/USDT: low volume
# ⏩ ID/USDT: low volume
# ⏩ ILV/USDT: low volume
# 🔍 IMX/USDT
# ⛔ IMX/USDT: нет сигнала
# 🔍 INJ/USDT
# ⛔ INJ/USDT: нет сигнала
# 🔍 IOST/USDT
# ⛔ IOST/USDT: нет сигнала
# 🔍 IOTA/USDT
# ⛔ IOTA/USDT: нет сигнала
# 🔍 IP/USDT
# ⛔ IP/USDT: нет сигнала
# 🔍 J/USDT
# ⛔ J/USDT: нет сигнала
# 🔍 JITOSOL/USDT
# ⛔ JITOSOL/USDT: нет сигнала
# ⏩ JOE/USDT: low volume
# 🔍 JTO/USDT
# ⛔ JTO/USDT: нет сигнала
# 🔍 JUP/USDT
# ⛔ JUP/USDT: нет сигнала
# 🔍 KAIA/USDT
# ⛔ KAIA/USDT: нет сигнала
# 🔍 KAITO/USDT
# ⛔ KAITO/USDT: нет сигнала
# ⏩ KDA/USDT: low volume
# 🔍 KMNO/USDT
# ⛔ KMNO/USDT: нет сигнала
# ⏩ KNC/USDT: low volume
# 🔍 KSM/USDT
# ⛔ KSM/USDT: нет сигнала
# 🔍 LAT/USDT
# ⛔ LAT/USDT: нет сигнала
# 🔍 LAYER/USDT
# ⛔ LAYER/USDT: нет сигнала
# 🔍 LDO/USDT
# ⛔ LDO/USDT: нет сигнала
# ⏩ LEO/USDT: low volume
# 🔍 LINK/USDT
# ⛔ LINK/USDT: нет сигнала
# ⏩ LOOKS/USDT: low volume
# 🔍 LPT/USDT
# ⛔ LPT/USDT: нет сигнала
# 🔍 LQTY/USDT
# ⛔ LQTY/USDT: нет сигнала
# ⏩ LRC/USDT: low volume
# ⏩ LSK/USDT: low volume
# 🔍 LTC/USDT
# ⛔ LTC/USDT: нет сигнала
# 🔍 LUNA/USDT
# ⛔ LUNA/USDT: нет сигнала
# 🔍 MAGIC/USDT
# ⛔ MAGIC/USDT: нет сигнала
# 🔍 MAJOR/USDT
# ⛔ MAJOR/USDT: нет сигнала
# 🔍 MANA/USDT
# ⛔ MANA/USDT: нет сигнала
# 🔍 MASK/USDT
# ⛔ MASK/USDT: нет сигнала
# 🔍 ME/USDT
# ⛔ ME/USDT: нет сигнала
# 🔍 MEME/USDT
# ⛔ MEME/USDT: нет сигнала
# 🔍 MEMEFI/USDT
# ⛔ MEMEFI/USDT: нет сигнала
# ⏩ MENGO/USDT: low volume
# 🔍 MERL/USDT
# ⛔ MERL/USDT: нет сигнала
# 🔍 METIS/USDT
# ⛔ METIS/USDT: нет сигнала
# 🔍 MEW/USDT
# ⛔ MEW/USDT: нет сигнала
# 🔍 MINA/USDT
# ⛔ MINA/USDT: нет сигнала
# ⏩ MLN/USDT: low volume
# 🔍 MOODENG/USDT
# ⛔ MOODENG/USDT: нет сигнала
# 🔍 MORPHO/USDT
# ⛔ MORPHO/USDT: нет сигнала
# 🔍 MOVE/USDT
# ⛔ MOVE/USDT: нет сигнала
# ⏩ NAVX/USDT: low volume
# ⏩ NC/USDT: low volume
# 🔍 NEAR/USDT
# ⛔ NEAR/USDT: нет сигнала
# 🔍 NEIRO/USDT
# ⛔ NEIRO/USDT: нет сигнала
# 🔍 NEO/USDT
# ⛔ NEO/USDT: нет сигнала
# ⏩ NFT/USDT: low volume
# 🔍 NMR/USDT
# ⛔ NMR/USDT: нет сигнала
# 🔍 NOT/USDT
# ⛔ NOT/USDT: нет сигнала
# ⏩ OAS/USDT: low volume
# 🔍 OKSOL/USDT
# ⛔ OKSOL/USDT: нет сигнала
# 🔍 OL/USDT
# ⛔ OL/USDT: нет сигнала
# 🔍 OM/USDT
# ⛔ OM/USDT: нет сигнала
# 🔍 OMI/USDT
# ⛔ OMI/USDT: нет сигнала
# 🔍 ONDO/USDT
# ⛔ ONDO/USDT: нет сигнала
# ⏩ ONE/USDT: low volume
# 🔍 ONT/USDT
# ⛔ ONT/USDT: нет сигнала
# 🔍 OP/USDT
# ⛔ OP/USDT: нет сигнала
# ⏩ ORBS/USDT: low volume
# 🔍 ORDI/USDT
# ⛔ ORDI/USDT: нет сигнала
# 🔍 PARTI/USDT
# ⛔ PARTI/USDT: нет сигнала
# 🔍 PAXG/USDT
# ⛔ PAXG/USDT: нет сигнала
# 🔍 PENDLE/USDT
# ⛔ PENDLE/USDT: нет сигнала
# 🔍 PENGU/USDT
# ⛔ PENGU/USDT: нет сигнала
# 🔍 PEOPLE/USDT
# ⛔ PEOPLE/USDT: нет сигнала
# 🔍 PEPE/USDT
# ⛔ PEPE/USDT: нет сигнала
# ⏩ PERP/USDT: low volume
# 🔍 PHA/USDT
# ⛔ PHA/USDT: нет сигнала
# 🔍 PI/USDT
# ⛔ PI/USDT: нет сигнала
# 🔍 PIXEL/USDT
# ⛔ PIXEL/USDT: нет сигнала
# 🔍 PNUT/USDT
# ⛔ PNUT/USDT: нет сигнала
# 🔍 POL/USDT
# ⛔ POL/USDT: нет сигнала
# ⏩ POR/USDT: low volume
# 🔍 PRCL/USDT
# ⛔ PRCL/USDT: нет сигнала
# 🔍 PROMPT/USDT
# ⛔ PROMPT/USDT: нет сигнала
# 🔍 PROVE/USDT
# ⛔ PROVE/USDT: контекст sideways — пропуск
# 🔍 PSTAKE/USDT
# ⛔ PSTAKE/USDT: нет сигнала
# 🔍 PYTH/USDT
# ⛔ PYTH/USDT: нет сигнала
# 🔍 PYUSD/USDT
# ⛔ PYUSD/USDT: нет сигнала
# 🔍 QTUM/USDT
# ⛔ QTUM/USDT: нет сигнала
# ⏩ RACA/USDT: low volume
# 🔍 RAY/USDT
# ⛔ RAY/USDT: нет сигнала
# 🔍 RDNT/USDT
# ⛔ RDNT/USDT: нет сигнала
# 🔍 RENDER/USDT
# ⛔ RENDER/USDT: нет сигнала
# 🔍 RESOLV/USDT
# ⛔ RESOLV/USDT: нет сигнала
# 🔍 RIO/USDT
# ⛔ RIO/USDT: нет сигнала
# ⏩ RON/USDT: low volume
# ⏩ RPL/USDT: low volume
# 🔍 RSR/USDT
# ⛔ RSR/USDT: нет сигнала
# 🔍 RSS3/USDT
# ⛔ RSS3/USDT: нет сигнала
# 🔍 RVN/USDT
# ⛔ RVN/USDT: нет сигнала
# 🔍 S/USDT
# ⛔ S/USDT: нет сигнала
# 🔍 SAFE/USDT
# ⛔ SAFE/USDT: нет сигнала
# 🔍 SAHARA/USDT
# ⛔ SAHARA/USDT: нет сигнала
# 🔍 SAND/USDT
# ⛔ SAND/USDT: нет сигнала
# 🔍 SATS/USDT
# ⛔ SATS/USDT: нет сигнала
# 🔍 SCR/USDT
# ⛔ SCR/USDT: нет сигнала
# 🔍 SD/USDT
# ⛔ SD/USDT: нет сигнала
# 🔍 SHIB/USDT
# ⛔ SHIB/USDT: нет сигнала
# 🔍 SKL/USDT
# ⛔ SKL/USDT: нет сигнала
# 🔍 SKY/USDT
# ⛔ SKY/USDT: нет сигнала
# 🔍 SLERF/USDT
# ⛔ SLERF/USDT: нет сигнала
# ⏩ SLP/USDT: low volume
# 🔍 SNT/USDT
# ⛔ SNT/USDT: нет сигнала
# 🔍 SNX/USDT
# ⛔ SNX/USDT: нет сигнала
# 🔍 SONIC/USDT
# ⛔ SONIC/USDT: нет сигнала
# 🔍 SOPH/USDT
# ⛔ SOPH/USDT: нет сигнала
# 🔍 SPK/USDT
# ⛔ SPK/USDT: нет сигнала
# ⏩ SPURS/USDT: low volume
# 🔍 SSV/USDT
# ⛔ SSV/USDT: нет сигнала
# 🔍 STETH/USDT
# ⛔ STETH/USDT: нет сигнала
# ⏩ STORJ/USDT: low volume
# 🔍 STRK/USDT
# ⛔ STRK/USDT: нет сигнала
# 🔍 STX/USDT
# ⛔ STX/USDT: нет сигнала
# 🔍 SUI/USDT
# ⛔ SUI/USDT: нет сигнала
# 🔍 SUSHI/USDT
# ⛔ SUSHI/USDT: нет сигнала
# 🔍 SWEAT/USDT
# ⛔ SWEAT/USDT: нет сигнала
# ⏩ SWFTC/USDT: low volume
# ⏩ T/USDT: low volume
# 🔍 THETA/USDT
# ⛔ THETA/USDT: нет сигнала
# 🔍 TIA/USDT
# ⛔ TIA/USDT: нет сигнала
# 🔍 TNSR/USDT
# ⛔ TNSR/USDT: нет сигнала
# 🔍 TON/USDT
# ⛔ TON/USDT: нет сигнала
# 🔍 TOSHI/USDT
# ⛔ TOSHI/USDT: нет сигнала
# ⏩ TRA/USDT: low volume
# 🔍 TRB/USDT
# ⛔ TRB/USDT: нет сигнала
# 🔍 TRUMP/USDT
# ⛔ TRUMP/USDT: нет сигнала
# 🔍 TRX/USDT
# ⛔ TRX/USDT: нет сигнала
# 🔍 TURBO/USDT
# ⛔ TURBO/USDT: нет сигнала
# ⏩ ULTI/USDT: low volume
# 🔍 UMA/USDT
# ⛔ UMA/USDT: нет сигнала
# 🔍 UNI/USDT
# ⛔ UNI/USDT: нет сигнала
# 🔍 USDC/USDT
# ⛔ USDC/USDT: нет сигнала
# 🔍 USDG/USDT
# ⛔ USDG/USDT: нет сигнала
# 🔍 USD1/USDT
# ⛔ USD1/USDT: нет сигнала
# 🔍 UXLINK/USDT
# ⛔ UXLINK/USDT: нет сигнала
# 🔍 VELO/USDT
# ⛔ VELO/USDT: нет сигнала
# ⏩ VELODROME/USDT: low volume
# 🔍 VINE/USDT
# ⛔ VINE/USDT: нет сигнала
# 🔍 VRA/USDT
# ⛔ VRA/USDT: нет сигнала
# 🔍 W/USDT
# ⛔ W/USDT: нет сигнала
# ⏩ WAXP/USDT: low volume
# 🔍 WCT/USDT
# ⛔ WCT/USDT: нет сигнала
# 🔍 WIF/USDT
# ⛔ WIF/USDT: нет сигнала
# 🔍 WINTOKEN/USDT
# ⛔ WINTOKEN/USDT: нет сигнала
# 🔍 WLD/USDT
# ⛔ WLD/USDT: нет сигнала
# 🔍 WOO/USDT
# ⛔ WOO/USDT: нет сигнала
# 🔍 XAUT/USDT
# ⛔ XAUT/USDT: нет сигнала
# 🔍 XCH/USDT
# ⛔ XCH/USDT: нет сигнала
# 🔍 XLM/USDT
# ⛔ XLM/USDT: нет сигнала
# 🔍 XPL/USDT
# ⛔ XPL/USDT: нет сигнала
# 🔍 XTZ/USDT
# ⛔ XTZ/USDT: нет сигнала
# 🔍 YB/USDT
# ⛔ YB/USDT: нет сигнала
# 🔍 YFI/USDT
# ⛔ YFI/USDT: нет сигнала
# 🔍 YGG/USDT
# ⛔ YGG/USDT: нет сигнала
# 🔍 ZBCN/USDT
# ⛔ ZBCN/USDT: нет сигнала
# 🔍 ZENT/USDT
# ⛔ ZENT/USDT: нет сигнала
# 🔍 ZETA/USDT
# ⛔ ZETA/USDT: нет сигнала
# 🔍 ZEUS/USDT
# ⛔ ZEUS/USDT: нет сигнала
# 🔍 ZIL/USDT
# ⛔ ZIL/USDT: нет сигнала
# 🔍 ZK/USDT
# ⛔ ZK/USDT: нет сигнала
# 🔍 ZKJ/USDT
# ⛔ ZKJ/USDT: нет сигнала
# 🔍 ZORA/USDT
# ⛔ ZORA/USDT: контекст sideways — пропуск
# 🔍 ZRO/USDT
# ⛔ ZRO/USDT: нет сигнала
# ⏩ ZRX/USDT: low volume
# ⏩ BTC/USDT:USDT-251024: low volume
# ⏩ BTC/USDT:USDT-251031: low volume
# ⏩ BTC/USDT:USDT-251128: low volume
# ⏩ BTC/USDT:USDT-251226: low volume
# ⏩ BTC/USDT:USDT-260327: low volume
# ⏩ BTC/USDT:USDT-260626: low volume
# ⏩ ETH/USDT:USDT-251024: low volume
# ⏩ ETH/USDT:USDT-251031: low volume
# ⏩ ETH/USDT:USDT-251226: low volume
# ⏩ ETH/USDT:USDT-260327: low volume
# ⏩ BTC/USDT:USDT: low volume
# ⏩ ETH/USDT:USDT: low volume
# ⏩ OKB/USDT:USDT: low volume
# ⏩ SOL/USDT:USDT: low volume
# ⏩ DOGE/USDT:USDT: low volume
# ⏩ XRP/USDT:USDT: low volume
# ⏩ BCH/USDT:USDT: low volume
# ⏩ PUMP/USDT:USDT: low volume
# ⏩ WLFI/USDT:USDT: low volume
# ⏩ LINEA/USDT:USDT: low volume
# ⏩ 0G/USDT:USDT: low volume
# ⏩ 1INCH/USDT:USDT: low volume
# ⏩ 2Z/USDT:USDT: low volume
# ⏩ A/USDT:USDT: low volume
# ⏩ AAVE/USDT:USDT: low volume
# ⏩ ACE/USDT:USDT: low volume
# ⏩ ACH/USDT:USDT: low volume
# ⏩ ACT/USDT:USDT: low volume
# ⏩ ADA/USDT:USDT: low volume
# ⏩ AERO/USDT:USDT: low volume
# ⏩ AEVO/USDT:USDT: low volume
# ⏩ AGLD/USDT:USDT: low volume
# ⏩ AI16Z/USDT:USDT: low volume
# ⏩ AIXBT/USDT:USDT: low volume
# ⏩ ALGO/USDT:USDT: low volume
# ⏩ ANIME/USDT:USDT: low volume
# ⏩ APE/USDT:USDT: low volume
# ⏩ API3/USDT:USDT: low volume
# ⏩ APT/USDT:USDT: low volume
# ⏩ AR/USDT:USDT: low volume
# ⏩ ARB/USDT:USDT: low volume
# ⏩ YB/USDT:USDT: low volume
# ⏩ YFI/USDT:USDT: low volume
# ⏩ YGG/USDT:USDT: low volume
# ⏩ ZBT/USDT:USDT: low volume
# ⏩ ZENT/USDT:USDT: low volume
# ⏩ ZETA/USDT:USDT: low volume
# ⏩ ZIL/USDT:USDT: low volume
# ⏩ ZK/USDT:USDT: low volume
# ⏩ ZORA/USDT:USDT: low volume
# ⏩ ZRO/USDT:USDT: low volume
# ⏩ ZRX/USDT:USDT: low volume
# ⏱ Waiting 60s before next scan...
#
# 🔍 BTC/USDT
# ⛔ BTC/USDT: нет сигнала
# 🔍 ETH/USDT
# ⛔ ETH/USDT: нет сигнала
# 🔍 OKB/USDT
# ⛔ OKB/USDT: нет сигнала
# 🔍 SOL/USDT
# ⛔ SOL/USDT: нет сигнала
# 🔍 DOGE/USDT
# ⛔ DOGE/USDT: нет сигнала
# 🔍 XRP/USDT
# ⛔ XRP/USDT: нет сигнала
# 🔍 BCH/USDT
# ⛔ BCH/USDT: нет сигнала
# 🔍 PUMP/USDT
# ⛔ PUMP/USDT: нет сигнала
# 🔍 WLFI/USDT
# ⛔ WLFI/USDT: нет сигнала
# 🔍 LINEA/USDT
# ⛔ LINEA/USDT: нет сигнала
# 🔍 1INCH/USDT
# ⛔ 1INCH/USDT: нет сигнала
# 🔍 A/USDT
# ⛔ A/USDT: нет сигнала
# 🔍 AAVE/USDT
# ⛔ AAVE/USDT: нет сигнала
# ⏩ ACA/USDT: low volume
# 🔍 ACE/USDT
# ⛔ ACE/USDT: нет сигнала
# 🔍 ACH/USDT
# ⛔ ACH/USDT: нет сигнала
# 🔍 ACT/USDT
# ⛔ ACT/USDT: нет сигнала
# 🔍 ADA/USDT
# ⛔ ADA/USDT: нет сигнала
# 🔍 AERGO/USDT
# ⛔ AERGO/USDT: нет сигнала
# 🔍 AEVO/USDT
# ⛔ AEVO/USDT: нет сигнала
# 🔍 AGLD/USDT
# ⛔ AGLD/USDT: нет сигнала
# 🔍 AIDOGE/USDT
# ⛔ AIDOGE/USDT: нет сигнала
# 🔍 AIXBT/USDT
# ⛔ AIXBT/USDT: нет сигнала
# 🔍 ALGO/USDT
# ⛔ ALGO/USDT: нет сигнала
# 🔍 ALPHA/USDT
# ⛔ ALPHA/USDT: нет сигнала
# 🔍 ANIME/USDT
# ⛔ ANIME/USDT: нет сигнала
# 🔍 APE/USDT
# ⛔ APE/USDT: нет сигнала
# 🔍 API3/USDT
# ⛔ API3/USDT: нет сигнала
# 🔍 APT/USDT
# ⛔ APT/USDT: нет сигнала
# 🔍 AR/USDT
# ⛔ AR/USDT: нет сигнала
# 🔍 ARB/USDT
# ⛔ ARB/USDT: нет сигнала
# ⏩ ARG/USDT: low volume
# 🔍 ARKM/USDT
# ⛔ ARKM/USDT: нет сигнала
# 🔍 ASP/USDT
# ⛔ ASP/USDT: нет сигнала
# 🔍 ASTR/USDT
# ⛔ ASTR/USDT: нет сигнала
# 🔍 ASTER/USDT
# ⛔ ASTER/USDT: контекст sideways — пропуск
# 🔍 ATH/USDT
# ⛔ ATH/USDT: нет сигнала
# 🔍 ATOM/USDT
# ⛔ ATOM/USDT: нет сигнала
# 🔍 AUCTION/USDT
# ⛔ AUCTION/USDT: нет сигнала
# 🔍 AVAX/USDT
# ⛔ AVAX/USDT: нет сигнала
# 🔍 AVNT/USDT
# ⛔ AVNT/USDT: нет сигнала
# 🔍 AXS/USDT
# ⛔ AXS/USDT: нет сигнала
# 🔍 BABYDOGE/USDT
# ⛔ BABYDOGE/USDT: нет сигнала
# 🔍 BABY/USDT
# ⛔ BABY/USDT: нет сигнала
# 🔍 BADGER/USDT
# ⛔ BADGER/USDT: нет сигнала
# ⏩ BAL/USDT: low volume
# ⏩ BAND/USDT: low volume
# 🔍 BANANA/USDT
# ⛔ BANANA/USDT: нет сигнала
# 🔍 BARD/USDT
# ⛔ BARD/USDT: нет сигнала
# 🔍 BAT/USDT
# ⛔ BAT/USDT: нет сигнала
# 🔍 BERA/USDT
# ⛔ BERA/USDT: нет сигнала
# 🔍 BETH/USDT
# ⛔ BETH/USDT: нет сигнала
# ⏩ BICO/USDT: low volume
# 🔍 BIGTIME/USDT
# ⛔ BIGTIME/USDT: нет сигнала
# 🔍 BIO/USDT
# ⛔ BIO/USDT: нет сигнала
# 🔍 BLUR/USDT
# ⛔ BLUR/USDT: нет сигнала
# 🔍 BNB/USDT
# ⛔ BNB/USDT: нет сигнала
# ⏩ BNT/USDT: low volume
# 🔍 BOME/USDT
# ⛔ BOME/USDT: нет сигнала
# 🔍 BONK/USDT
# ⛔ BONK/USDT: нет сигнала
# 🔍 CATI/USDT
# ⛔ CATI/USDT: нет сигнала
# 🔍 CAT/USDT
# ⛔ CAT/USDT: нет сигнала
# 🔍 CELO/USDT
# ⛔ CELO/USDT: нет сигнала
# ⏩ CELR/USDT: low volume
# 🔍 CETUS/USDT
# ⛔ CETUS/USDT: нет сигнала
# 🔍 CFG/USDT
# ⛔ CFG/USDT: нет сигнала
# 🔍 CFX/USDT
# ⛔ CFX/USDT: нет сигнала
# 🔍 CHZ/USDT
# ⛔ CHZ/USDT: нет сигнала
# ⏩ CITY/USDT: low volume
# 🔍 CLV/USDT
# ⛔ CLV/USDT: нет сигнала
# 🔍 COMP/USDT
# ⛔ COMP/USDT: нет сигнала
# 🔍 CORE/USDT
# ⛔ CORE/USDT: нет сигнала
# 🔍 CRO/USDT
# ⛔ CRO/USDT: нет сигнала
# 🔍 CRV/USDT
# ⛔ CRV/USDT: нет сигнала
# 🔍 CSPR/USDT
# ⛔ CSPR/USDT: нет сигнала
# 🔍 CTC/USDT
# ⛔ CTC/USDT: нет сигнала
# 🔍 CVC/USDT
# ⛔ CVC/USDT: нет сигнала
# 🔍 CVX/USDT
# ⛔ CVX/USDT: нет сигнала
# 🔍 CXT/USDT
# ⛔ CXT/USDT: нет сигнала
# 🔍 DAI/USDT
# ⛔ DAI/USDT: нет сигнала
# ⏩ DAO/USDT: low volume
# 🔍 DEGEN/USDT
# ⛔ DEGEN/USDT: нет сигнала
# ⏩ DEP/USDT: low volume
# ⏩ DGB/USDT: low volume
# 🔍 DOGS/USDT
# ⛔ DOGS/USDT: нет сигнала
# 🔍 DOOD/USDT
# ⛔ DOOD/USDT: контекст sideways — пропуск
# ⏩ DORA/USDT: low volume
# 🔍 DOT/USDT
# ⛔ DOT/USDT: нет сигнала
# 🔍 DUCK/USDT
# ⛔ DUCK/USDT: нет сигнала
# 🔍 DYDX/USDT
# ⛔ DYDX/USDT: нет сигнала
# ⏩ EGLD/USDT: low volume
# 🔍 EIGEN/USDT
# ⛔ EIGEN/USDT: нет сигнала
# ⏩ ELF/USDT: low volume
# ⏩ ELON/USDT: low volume
# 🔍 ENA/USDT
# ⛔ ENA/USDT: нет сигнала
# ⏩ ENJ/USDT: low volume
# 🔍 ENS/USDT
# ⛔ ENS/USDT: нет сигнала
# 🔍 ETC/USDT
# ⛔ ETC/USDT: нет сигнала
# 🔍 ETHW/USDT
# ⛔ ETHW/USDT: нет сигнала
# 🔍 ETHFI/USDT
# ⛔ ETHFI/USDT: нет сигнала
# 🔍 FET/USDT
# ⛔ FET/USDT: нет сигнала
# 🔍 FIL/USDT
# ⛔ FIL/USDT: нет сигнала
# 🔍 FLM/USDT
# ⛔ FLM/USDT: нет сигнала
# 🔍 FLOW/USDT
# ⛔ FLOW/USDT: нет сигнала
# 🔍 FLOKI/USDT
# ⛔ FLOKI/USDT: нет сигнала
# 🔍 FLR/USDT
# ⛔ FLR/USDT: нет сигнала
# 🔍 FLUID/USDT
# ⛔ FLUID/USDT: нет сигнала
# ⏩ FOXY/USDT: low volume
# ⏩ FXS/USDT: low volume
# ⏩ G/USDT: low volume
# 🔍 GALA/USDT
# ⛔ GALA/USDT: нет сигнала
# ⏩ GALFT/USDT: low volume
# 🔍 GAS/USDT
# ⛔ GAS/USDT: нет сигнала
# ⏩ GEAR/USDT: low volume
# ⏩ GHST/USDT: low volume
# 🔍 GLM/USDT
# ⛔ GLM/USDT: нет сигнала
# 🔍 GMT/USDT
# ⛔ GMT/USDT: нет сигнала
# 🔍 GMX/USDT
# ⛔ GMX/USDT: нет сигнала
# 🔍 GOAT/USDT
# ⛔ GOAT/USDT: нет сигнала
# 🔍 GODS/USDT
# ⛔ GODS/USDT: нет сигнала
# 🔍 GRT/USDT
# ⛔ GRT/USDT: нет сигнала
# 🔍 HBAR/USDT
# ⛔ HBAR/USDT: нет сигнала
# 🔍 HMSTR/USDT
# ⛔ HMSTR/USDT: нет сигнала
# 🔍 HUMA/USDT
# ⛔ HUMA/USDT: нет сигнала
# 🔍 ICE/USDT
# ⛔ ICE/USDT: нет сигнала
# 🔍 ICP/USDT
# ⛔ ICP/USDT: нет сигнала
# ⏩ ICX/USDT: low volume
# ⏩ ID/USDT: low volume
# ⏩ ILV/USDT: low volume
# 🔍 IMX/USDT
# ⛔ IMX/USDT: нет сигнала
# 🔍 INJ/USDT
# ⛔ INJ/USDT: нет сигнала
# 🔍 IOST/USDT
# ⛔ IOST/USDT: нет сигнала
# 🔍 IOTA/USDT
# ⛔ IOTA/USDT: нет сигнала
# 🔍 IP/USDT
# ⛔ IP/USDT: нет сигнала
# 🔍 J/USDT
# ⛔ J/USDT: нет сигнала
# 🔍 JITOSOL/USDT
# ⛔ JITOSOL/USDT: нет сигнала
# ⏩ JOE/USDT: low volume
# 🔍 JTO/USDT
# ⛔ JTO/USDT: нет сигнала
# 🔍 JUP/USDT
# ⛔ JUP/USDT: нет сигнала
# 🔍 KAIA/USDT
# ⛔ KAIA/USDT: нет сигнала
# 🔍 KAITO/USDT
# ⛔ KAITO/USDT: нет сигнала
# ⏩ KDA/USDT: low volume
# 🔍 KMNO/USDT
# ⛔ KMNO/USDT: нет сигнала
# ⏩ KNC/USDT: low volume
# 🔍 KSM/USDT
# ⛔ KSM/USDT: нет сигнала
# 🔍 LAT/USDT
# ⛔ LAT/USDT: нет сигнала
# 🔍 LAYER/USDT
# ⛔ LAYER/USDT: нет сигнала
# 🔍 LDO/USDT
# ⛔ LDO/USDT: нет сигнала
# ⏩ LEO/USDT: low volume
# 🔍 LINK/USDT
# ⛔ LINK/USDT: нет сигнала
# ⏩ LOOKS/USDT: low volume
# 🔍 LPT/USDT
# ⛔ LPT/USDT: нет сигнала
# 🔍 LQTY/USDT
# ⛔ LQTY/USDT: нет сигнала
# ⏩ LRC/USDT: low volume
# ⏩ LSK/USDT: low volume
# 🔍 LTC/USDT
# ⛔ LTC/USDT: нет сигнала
# 🔍 LUNA/USDT
# ⛔ LUNA/USDT: нет сигнала
# 🔍 MAGIC/USDT
# ⛔ MAGIC/USDT: нет сигнала
# 🔍 MAJOR/USDT
# ⛔ MAJOR/USDT: нет сигнала
# 🔍 MANA/USDT
# ⛔ MANA/USDT: нет сигнала
# 🔍 MASK/USDT
# ⛔ MASK/USDT: нет сигнала
# 🔍 ME/USDT
# ⛔ ME/USDT: нет сигнала
# 🔍 MEME/USDT
# ⛔ MEME/USDT: нет сигнала
# 🔍 MEMEFI/USDT
# ⛔ MEMEFI/USDT: нет сигнала
# ⏩ MENGO/USDT: low volume
# 🔍 MERL/USDT
# ⛔ MERL/USDT: нет сигнала
# 🔍 METIS/USDT
# ⛔ METIS/USDT: нет сигнала
# 🔍 MEW/USDT
# ⛔ MEW/USDT: нет сигнала
# 🔍 MINA/USDT
# ⛔ MINA/USDT: нет сигнала
# ⏩ MLN/USDT: low volume
# 🔍 MOODENG/USDT
# ⛔ MOODENG/USDT: нет сигнала
# 🔍 MORPHO/USDT
# ⛔ MORPHO/USDT: нет сигнала
# 🔍 MOVE/USDT
# ⛔ MOVE/USDT: нет сигнала
# ⏩ NAVX/USDT: low volume
# ⏩ NC/USDT: low volume
# 🔍 NEAR/USDT
# ⛔ NEAR/USDT: нет сигнала
# 🔍 NEIRO/USDT
# ⛔ NEIRO/USDT: нет сигнала
# 🔍 NEO/USDT
# ⛔ NEO/USDT: нет сигнала
# ⏩ NFT/USDT: low volume
# 🔍 NMR/USDT
# ⛔ NMR/USDT: нет сигнала
# 🔍 NOT/USDT
# ⛔ NOT/USDT: нет сигнала
# ⏩ OAS/USDT: low volume
# 🔍 OKSOL/USDT
# ⛔ OKSOL/USDT: нет сигнала
# 🔍 OL/USDT
# ⛔ OL/USDT: нет сигнала
# 🔍 OM/USDT
# ⛔ OM/USDT: нет сигнала
# 🔍 OMI/USDT
# ⛔ OMI/USDT: нет сигнала
# 🔍 ONDO/USDT
# ⛔ ONDO/USDT: нет сигнала
# ⏩ ONE/USDT: low volume
# 🔍 ONT/USDT
# ⛔ ONT/USDT: нет сигнала
# 🔍 OP/USDT
# ⛔ OP/USDT: нет сигнала
# ⏩ ORBS/USDT: low volume
# 🔍 ORDI/USDT
# ⛔ ORDI/USDT: нет сигнала
# 🔍 PARTI/USDT
# ⛔ PARTI/USDT: нет сигнала
# 🔍 PAXG/USDT
# ⛔ PAXG/USDT: нет сигнала
# 🔍 PENDLE/USDT
# ⛔ PENDLE/USDT: нет сигнала
# 🔍 PENGU/USDT
# ⛔ PENGU/USDT: нет сигнала
# 🔍 PEOPLE/USDT
# ⛔ PEOPLE/USDT: нет сигнала
# 🔍 PEPE/USDT
# ⛔ PEPE/USDT: нет сигнала
# ⏩ PERP/USDT: low volume
# 🔍 PHA/USDT
# ⛔ PHA/USDT: нет сигнала
# 🔍 PI/USDT
# ⛔ PI/USDT: нет сигнала
# 🔍 PIXEL/USDT
# ⛔ PIXEL/USDT: нет сигнала
# 🔍 PNUT/USDT
# ⛔ PNUT/USDT: нет сигнала
# 🔍 POL/USDT
# ⛔ POL/USDT: нет сигнала
# ⏩ POR/USDT: low volume
# 🔍 PRCL/USDT
# ⛔ PRCL/USDT: нет сигнала
# 🔍 PROMPT/USDT
# ⛔ PROMPT/USDT: нет сигнала
# 🔍 PROVE/USDT
# ⛔ PROVE/USDT: контекст sideways — пропуск
# 🔍 PSTAKE/USDT
# ⛔ PSTAKE/USDT: нет сигнала
# 🔍 PYTH/USDT
# ⛔ PYTH/USDT: нет сигнала
# 🔍 PYUSD/USDT
# ⛔ PYUSD/USDT: нет сигнала
# 🔍 QTUM/USDT
# ⛔ QTUM/USDT: нет сигнала
# ⏩ RACA/USDT: low volume
# 🔍 RAY/USDT
# ⛔ RAY/USDT: нет сигнала
# 🔍 RDNT/USDT
# ⛔ RDNT/USDT: нет сигнала
# 🔍 RENDER/USDT
# ⛔ RENDER/USDT: нет сигнала
# 🔍 RESOLV/USDT
# ⛔ RESOLV/USDT: нет сигнала
# 🔍 RIO/USDT
# ⛔ RIO/USDT: нет сигнала
# ⏩ RON/USDT: low volume
# ⏩ RPL/USDT: low volume
# 🔍 RSR/USDT
# ⛔ RSR/USDT: нет сигнала
# 🔍 RSS3/USDT
# ⛔ RSS3/USDT: нет сигнала
# 🔍 RVN/USDT
# ⛔ RVN/USDT: нет сигнала
# 🔍 S/USDT
# ⛔ S/USDT: нет сигнала
# 🔍 SAFE/USDT
# ⛔ SAFE/USDT: нет сигнала
# 🔍 SAHARA/USDT
# ⛔ SAHARA/USDT: нет сигнала
# 🔍 SAND/USDT
# ⛔ SAND/USDT: нет сигнала
# 🔍 SATS/USDT
# ⛔ SATS/USDT: нет сигнала
# 🔍 SCR/USDT
# ⛔ SCR/USDT: нет сигнала
# 🔍 SD/USDT
# ⛔ SD/USDT: нет сигнала
# 🔍 SHIB/USDT
# ⛔ SHIB/USDT: нет сигнала
# 🔍 SKL/USDT
# ⛔ SKL/USDT: нет сигнала
# 🔍 SKY/USDT
# ⛔ SKY/USDT: нет сигнала
# 🔍 SLERF/USDT
# ⛔ SLERF/USDT: нет сигнала
# ⏩ SLP/USDT: low volume
# 🔍 SNT/USDT
# ⛔ SNT/USDT: нет сигнала
# 🔍 SNX/USDT
# ⛔ SNX/USDT: нет сигнала
# 🔍 SONIC/USDT
# ⛔ SONIC/USDT: нет сигнала
# 🔍 SOPH/USDT
# ⛔ SOPH/USDT: нет сигнала
# 🔍 SPK/USDT
# ⛔ SPK/USDT: нет сигнала
# ⏩ SPURS/USDT: low volume
# 🔍 SSV/USDT
# ⛔ SSV/USDT: нет сигнала
# 🔍 STETH/USDT
# ⛔ STETH/USDT: нет сигнала
# ⏩ STORJ/USDT: low volume
# 🔍 STRK/USDT
# ⛔ STRK/USDT: нет сигнала
# 🔍 STX/USDT
# ⛔ STX/USDT: нет сигнала
# 🔍 SUI/USDT
# ⛔ SUI/USDT: нет сигнала
# 🔍 SUSHI/USDT
# ⛔ SUSHI/USDT: нет сигнала
# 🔍 SWEAT/USDT
# ⛔ SWEAT/USDT: нет сигнала
# ⏩ SWFTC/USDT: low volume
# ⏩ T/USDT: low volume
# 🔍 THETA/USDT
# ⛔ THETA/USDT: нет сигнала
# 🔍 TIA/USDT
# ⛔ TIA/USDT: нет сигнала
# 🔍 TNSR/USDT
# ⛔ TNSR/USDT: нет сигнала
# 🔍 TON/USDT
# ⛔ TON/USDT: нет сигнала
# 🔍 TOSHI/USDT
# ⛔ TOSHI/USDT: нет сигнала
# ⏩ TRA/USDT: low volume
# 🔍 TRB/USDT
# ⛔ TRB/USDT: нет сигнала
# 🔍 TRUMP/USDT
# ⛔ TRUMP/USDT: нет сигнала
# 🔍 TRX/USDT
# ⛔ TRX/USDT: нет сигнала
# 🔍 TURBO/USDT
# ⛔ TURBO/USDT: нет сигнала
# ⏩ ULTI/USDT: low volume
# 🔍 UMA/USDT
# ⛔ UMA/USDT: нет сигнала
# 🔍 UNI/USDT
# ⛔ UNI/USDT: нет сигнала
# 🔍 USDC/USDT
# ⛔ USDC/USDT: нет сигнала
# 🔍 USDG/USDT
# ⛔ USDG/USDT: нет сигнала
# 🔍 USD1/USDT
# ⛔ USD1/USDT: нет сигнала
# 🔍 UXLINK/USDT
# ⛔ UXLINK/USDT: нет сигнала
# 🔍 VELO/USDT
# ⛔ VELO/USDT: нет сигнала
# ⏩ VELODROME/USDT: low volume
# 🔍 VINE/USDT
# ⛔ VINE/USDT: нет сигнала
# 🔍 VRA/USDT
# ⛔ VRA/USDT: нет сигнала
# 🔍 W/USDT
# ⛔ W/USDT: нет сигнала
# ⏩ WAXP/USDT: low volume
# 🔍 WCT/USDT
# ⛔ WCT/USDT: нет сигнала
# 🔍 WIF/USDT
# ⛔ WIF/USDT: нет сигнала
# 🔍 WINTOKEN/USDT
# ⛔ WINTOKEN/USDT: нет сигнала
# 🔍 WLD/USDT
# ⛔ WLD/USDT: нет сигнала
# 🔍 WOO/USDT
# ⛔ WOO/USDT: нет сигнала
# 🔍 XAUT/USDT
# ⛔ XAUT/USDT: нет сигнала
# 🔍 XCH/USDT
# ⛔ XCH/USDT: нет сигнала
# 🔍 XLM/USDT
# ⛔ XLM/USDT: нет сигнала
# 🔍 XPL/USDT
# ⛔ XPL/USDT: нет сигнала
# 🔍 XTZ/USDT
# ⛔ XTZ/USDT: нет сигнала
# 🔍 YB/USDT
# ⛔ YB/USDT: нет сигнала
# 🔍 YFI/USDT
# ⛔ YFI/USDT: нет сигнала
# 🔍 YGG/USDT
# ⛔ YGG/USDT: нет сигнала
# 🔍 ZBCN/USDT
# ⛔ ZBCN/USDT: нет сигнала
# 🔍 ZENT/USDT
# ⛔ ZENT/USDT: нет сигнала
# 🔍 ZETA/USDT
# ⛔ ZETA/USDT: нет сигнала
# 🔍 ZEUS/USDT
# ⛔ ZEUS/USDT: нет сигнала
# 🔍 ZIL/USDT
# ⛔ ZIL/USDT: нет сигнала
# 🔍 ZK/USDT
# ⛔ ZK/USDT: нет сигнала
# 🔍 ZKJ/USDT
# ⛔ ZKJ/USDT: нет сигнала
# 🔍 ZORA/USDT
# ⛔ ZORA/USDT: контекст sideways — пропуск
# 🔍 ZRO/USDT
# ⛔ ZRO/USDT: нет сигнала
# ⏩ ZRX/USDT: low volume
# ⏩ BTC/USDT:USDT-251024: low volume
# ⏩ BTC/USDT:USDT-251031: low volume
# ⏩ BTC/USDT:USDT-251128: low volume
# ⏩ BTC/USDT:USDT-251226: low volume
# ⏩ BTC/USDT:USDT-260327: low volume
# ⏩ BTC/USDT:USDT-260626: low volume
# ⏩ ETH/USDT:USDT-251024: low volume
# ⏩ ETH/USDT:USDT-251031: low volume
# ⏩ ETH/USDT:USDT-251226: low volume
# ⏩ ETH/USDT:USDT-260327: low volume
# ⏩ BTC/USDT:USDT: low volume
# ⏩ ETH/USDT:USDT: low volume
# ⏩ OKB/USDT:USDT: low volume
# ⏩ SOL/USDT:USDT: low volume
# ⏩ DOGE/USDT:USDT: low volume
# ⏩ XRP/USDT:USDT: low volume
# ⏩ BCH/USDT:USDT: low volume
# ⏩ PUMP/USDT:USDT: low volume
# ⏩ WLFI/USDT:USDT: low volume
# ⏩ LINEA/USDT:USDT: low volume
# ⏩ 0G/USDT:USDT: low volume
# ⏩ 1INCH/USDT:USDT: low volume
# ⏩ 2Z/USDT:USDT: low volume
# ⏩ A/USDT:USDT: low volume
# ⏩ AAVE/USDT:USDT: low volume
# ⏩ ACE/USDT:USDT: low volume
# ⏩ ACH/USDT:USDT: low volume
# ⏩ ACT/USDT:USDT: low volume
# ⏩ ADA/USDT:USDT: low volume
# ⏩ AERO/USDT:USDT: low volume
# ⏩ W/USDT:USDT: low volume
# ⏩ WAL/USDT:USDT: low volume
# ⏩ WCT/USDT:USDT: low volume
# ⏩ WIF/USDT:USDT: low volume
# ⏩ WLD/USDT:USDT: low volume
# ⏩ WOO/USDT:USDT: low volume
# ⏩ XAN/USDT:USDT: low volume
# ⏩ XAUT/USDT:USDT: low volume
# ⏩ XLM/USDT:USDT: low volume
# ⏩ XPL/USDT:USDT: low volume
# ⏩ XTZ/USDT:USDT: low volume
# ⏩ YB/USDT:USDT: low volume
# ⏩ YFI/USDT:USDT: low volume
# ⏩ YGG/USDT:USDT: low volume
# ⏩ ZBT/USDT:USDT: low volume
# ⏩ ZENT/USDT:USDT: low volume
# ⏩ ZETA/USDT:USDT: low volume
# ⏩ ZIL/USDT:USDT: low volume
# ⏩ ZK/USDT:USDT: low volume
# ⏩ ZORA/USDT:USDT: low volume
# ⏩ ZRO/USDT:USDT: low volume
# ⏩ ZRX/USDT:USDT: low volume
# ⏱ Waiting 60s before next scan...
#
# 🔍 BTC/USDT
# ⛔ BTC/USDT: нет сигнала
# 🔍 ETH/USDT
# ⛔ ETH/USDT: нет сигнала
# 🔍 OKB/USDT
# ⛔ OKB/USDT: нет сигнала
# 🔍 SOL/USDT
# ⛔ SOL/USDT: нет сигнала
# 🔍 DOGE/USDT
# ⛔ DOGE/USDT: нет сигнала
# 🔍 XRP/USDT
# ⛔ XRP/USDT: нет сигнала
# 🔍 BCH/USDT
# ⛔ BCH/USDT: нет сигнала
# 🔍 PUMP/USDT
# ⛔ PUMP/USDT: нет сигнала
# 🔍 WLFI/USDT
# ⛔ WLFI/USDT: нет сигнала
# 🔍 LINEA/USDT
# ⛔ LINEA/USDT: нет сигнала
# 🔍 1INCH/USDT
# ⛔ 1INCH/USDT: нет сигнала
# 🔍 A/USDT
# ⛔ A/USDT: нет сигнала
# 🔍 AAVE/USDT
# ⛔ AAVE/USDT: нет сигнала
# ⏩ ACA/USDT: low volume
# 🔍 ACE/USDT
# ⛔ ACE/USDT: нет сигнала
# 🔍 ACH/USDT
# ⛔ ACH/USDT: нет сигнала
# 🔍 ACT/USDT
# ⛔ ACT/USDT: нет сигнала
# 🔍 ADA/USDT
# ⛔ ADA/USDT: нет сигнала
# 🔍 AERGO/USDT
# ⛔ AERGO/USDT: нет сигнала
# 🔍 AEVO/USDT
# ⛔ AEVO/USDT: нет сигнала
# 🔍 AGLD/USDT
# ⛔ AGLD/USDT: нет сигнала
# 🔍 AIDOGE/USDT
# ⛔ AIDOGE/USDT: нет сигнала
# 🔍 AIXBT/USDT
# ⛔ AIXBT/USDT: нет сигнала
# 🔍 ALGO/USDT
# ⛔ ALGO/USDT: нет сигнала
# 🔍 ALPHA/USDT
# ⛔ ALPHA/USDT: нет сигнала
# 🔍 ANIME/USDT
# ⛔ ANIME/USDT: нет сигнала
# 🔍 APE/USDT
# ⛔ APE/USDT: нет сигнала
# 🔍 API3/USDT
# ⛔ API3/USDT: нет сигнала
# 🔍 APT/USDT
# ⛔ APT/USDT: нет сигнала
# 🔍 AR/USDT
# ⛔ AR/USDT: нет сигнала
# 🔍 ARB/USDT
# ⛔ ARB/USDT: нет сигнала
# ⏩ ARG/USDT: low volume
# 🔍 ARKM/USDT
# ⛔ ARKM/USDT: нет сигнала
# 🔍 ASP/USDT
# ⛔ ASP/USDT: нет сигнала
# 🔍 ASTR/USDT
# ⛔ ASTR/USDT: нет сигнала
# 🔍 ASTER/USDT
# ⛔ ASTER/USDT: контекст sideways — пропуск
# 🔍 ATH/USDT
# ⛔ ATH/USDT: нет сигнала
# 🔍 ATOM/USDT
# ⛔ ATOM/USDT: нет сигнала
# 🔍 AUCTION/USDT
# ⛔ AUCTION/USDT: нет сигнала
# 🔍 AVAX/USDT
# ⛔ AVAX/USDT: нет сигнала
# 🔍 AVNT/USDT
# ⛔ AVNT/USDT: нет сигнала
# 🔍 AXS/USDT
# ⛔ AXS/USDT: нет сигнала
# 🔍 BABYDOGE/USDT
# ⛔ BABYDOGE/USDT: нет сигнала
# 🔍 BABY/USDT
# ⛔ BABY/USDT: нет сигнала
# 🔍 BADGER/USDT
# ⛔ BADGER/USDT: нет сигнала
# ⏩ BAL/USDT: low volume
# ⏩ BAND/USDT: low volume
# 🔍 BANANA/USDT
# ⛔ BANANA/USDT: нет сигнала
# 🔍 BARD/USDT
# ⛔ BARD/USDT: нет сигнала
# 🔍 BAT/USDT
# ⛔ BAT/USDT: нет сигнала
# 🔍 BERA/USDT
# ⛔ BERA/USDT: нет сигнала
# 🔍 BETH/USDT
# ⛔ BETH/USDT: нет сигнала
# ⏩ BICO/USDT: low volume
# 🔍 BIGTIME/USDT
# ⛔ BIGTIME/USDT: нет сигнала
# 🔍 BIO/USDT
# ⛔ BIO/USDT: нет сигнала
# 🔍 BLUR/USDT
# ⛔ BLUR/USDT: нет сигнала
# 🔍 BNB/USDT
# ⛔ BNB/USDT: нет сигнала
# ⏩ BNT/USDT: low volume
# 🔍 BOME/USDT
# ⛔ BOME/USDT: нет сигнала
# 🔍 BONK/USDT
# ⛔ BONK/USDT: нет сигнала
# 🔍 CATI/USDT
# ⛔ CATI/USDT: нет сигнала
# 🔍 CAT/USDT
# ⛔ CAT/USDT: нет сигнала
# 🔍 CELO/USDT
# ⛔ CELO/USDT: нет сигнала
# ⏩ CELR/USDT: low volume
# 🔍 CETUS/USDT
# ⛔ CETUS/USDT: нет сигнала
# 🔍 CFG/USDT
# ⛔ CFG/USDT: нет сигнала
# 🔍 CFX/USDT
# ⛔ CFX/USDT: нет сигнала
# 🔍 CHZ/USDT
# ⛔ CHZ/USDT: нет сигнала
# ⏩ CITY/USDT: low volume
# 🔍 CLV/USDT
# ⛔ CLV/USDT: нет сигнала
# 🔍 COMP/USDT
# ⛔ COMP/USDT: нет сигнала
# 🔍 CORE/USDT
# ⛔ CORE/USDT: нет сигнала
# 🔍 CRO/USDT
# ⛔ CRO/USDT: нет сигнала
# 🔍 CRV/USDT
# ⛔ CRV/USDT: нет сигнала
# 🔍 CSPR/USDT
# ⛔ CSPR/USDT: нет сигнала
# 🔍 CTC/USDT
# ⛔ CTC/USDT: нет сигнала
# 🔍 CVC/USDT
# ⛔ CVC/USDT: нет сигнала
# 🔍 CVX/USDT
# ⛔ CVX/USDT: нет сигнала
# 🔍 CXT/USDT
# ⛔ CXT/USDT: нет сигнала
# 🔍 DAI/USDT
# ⛔ DAI/USDT: нет сигнала
# ⏩ DAO/USDT: low volume
# 🔍 DEGEN/USDT
# ⛔ DEGEN/USDT: нет сигнала
# ⏩ DEP/USDT: low volume
# ⏩ DGB/USDT: low volume
# 🔍 DOGS/USDT
# ⛔ DOGS/USDT: нет сигнала
# 🔍 DOOD/USDT
# ⛔ DOOD/USDT: контекст sideways — пропуск
# ⏩ DORA/USDT: low volume
# 🔍 DOT/USDT
# ⛔ DOT/USDT: нет сигнала
# 🔍 DUCK/USDT
# ⛔ DUCK/USDT: нет сигнала
# 🔍 DYDX/USDT
# ⛔ DYDX/USDT: нет сигнала
# ⏩ EGLD/USDT: low volume
# 🔍 EIGEN/USDT
# ⛔ EIGEN/USDT: нет сигнала
# ⏩ ELF/USDT: low volume
# ⏩ ELON/USDT: low volume
# 🔍 ENA/USDT
# ⛔ ENA/USDT: нет сигнала
# ⏩ ENJ/USDT: low volume
# 🔍 ENS/USDT
# ⛔ ENS/USDT: нет сигнала
# 🔍 ETC/USDT
# ⛔ ETC/USDT: нет сигнала
# 🔍 ETHW/USDT
# ⛔ ETHW/USDT: нет сигнала
# 🔍 ETHFI/USDT
# ⛔ ETHFI/USDT: нет сигнала
# 🔍 FET/USDT
# ⛔ FET/USDT: нет сигнала
# 🔍 FIL/USDT
# ⛔ FIL/USDT: нет сигнала
# 🔍 FLM/USDT
# ⛔ FLM/USDT: нет сигнала
# 🔍 FLOW/USDT
# ⛔ FLOW/USDT: нет сигнала
# 🔍 FLOKI/USDT
# ⛔ FLOKI/USDT: нет сигнала
# 🔍 FLR/USDT
# ⛔ FLR/USDT: нет сигнала
# 🔍 FLUID/USDT
# ⛔ FLUID/USDT: нет сигнала
# ⏩ FOXY/USDT: low volume
# ⏩ FXS/USDT: low volume
# ⏩ G/USDT: low volume
# 🔍 GALA/USDT
# ⛔ GALA/USDT: нет сигнала
# ⏩ GALFT/USDT: low volume
# 🔍 GAS/USDT
# ⛔ GAS/USDT: нет сигнала
# ⏩ GEAR/USDT: low volume
# ⏩ GHST/USDT: low volume
# 🔍 GLM/USDT
# ⛔ GLM/USDT: нет сигнала
# 🔍 GMT/USDT
# ⛔ GMT/USDT: нет сигнала
# 🔍 GMX/USDT
# ⛔ GMX/USDT: нет сигнала
# 🔍 GOAT/USDT
# ⛔ GOAT/USDT: нет сигнала
# 🔍 GODS/USDT
# ⛔ GODS/USDT: нет сигнала
# 🔍 GRT/USDT
# ⛔ GRT/USDT: нет сигнала
# 🔍 HBAR/USDT
# ⛔ HBAR/USDT: нет сигнала
# 🔍 HMSTR/USDT
# ⛔ HMSTR/USDT: нет сигнала
# 🔍 HUMA/USDT
# ⛔ HUMA/USDT: нет сигнала
# 🔍 ICE/USDT
# ⛔ ICE/USDT: нет сигнала
# 🔍 ICP/USDT
# ⛔ ICP/USDT: нет сигнала
# ⏩ ICX/USDT: low volume
# ⏩ ID/USDT: low volume
# ⏩ ILV/USDT: low volume
# 🔍 IMX/USDT
# ⛔ IMX/USDT: нет сигнала
# 🔍 INJ/USDT
# ⛔ INJ/USDT: нет сигнала
# 🔍 IOST/USDT
# ⛔ IOST/USDT: нет сигнала
# 🔍 IOTA/USDT
# ⛔ IOTA/USDT: нет сигнала
# 🔍 IP/USDT
# ⛔ IP/USDT: нет сигнала
# 🔍 J/USDT
# ⛔ J/USDT: нет сигнала
# 🔍 JITOSOL/USDT
# ⛔ JITOSOL/USDT: нет сигнала
# ⏩ JOE/USDT: low volume
# 🔍 JTO/USDT
# ⛔ JTO/USDT: нет сигнала
# 🔍 JUP/USDT
# ⛔ JUP/USDT: нет сигнала
# 🔍 KAIA/USDT
# ⛔ KAIA/USDT: нет сигнала
# 🔍 KAITO/USDT
# ⛔ KAITO/USDT: нет сигнала
# ⏩ KDA/USDT: low volume
# 🔍 KMNO/USDT
# ⛔ KMNO/USDT: нет сигнала
# ⏩ KNC/USDT: low volume
# 🔍 KSM/USDT
# ⛔ KSM/USDT: нет сигнала
# 🔍 LAT/USDT
# ⛔ LAT/USDT: нет сигнала
# 🔍 LAYER/USDT
# ⛔ LAYER/USDT: нет сигнала
# 🔍 LDO/USDT
# ⛔ LDO/USDT: нет сигнала
# ⏩ LEO/USDT: low volume
# 🔍 LINK/USDT
# ⛔ LINK/USDT: нет сигнала
# ⏩ LOOKS/USDT: low volume
# 🔍 LPT/USDT
# ⛔ LPT/USDT: нет сигнала
# 🔍 LQTY/USDT
# ⛔ LQTY/USDT: нет сигнала
# ⏩ LRC/USDT: low volume
# ⏩ LSK/USDT: low volume
# 🔍 LTC/USDT
# ⛔ LTC/USDT: нет сигнала
# 🔍 LUNA/USDT
# ⛔ LUNA/USDT: нет сигнала
# 🔍 MAGIC/USDT
# ⛔ MAGIC/USDT: нет сигнала
# 🔍 MAJOR/USDT
# ⛔ MAJOR/USDT: нет сигнала
# 🔍 MANA/USDT
# ⛔ MANA/USDT: нет сигнала
# 🔍 MASK/USDT
# ⛔ MASK/USDT: нет сигнала
# 🔍 ME/USDT
# ⛔ ME/USDT: нет сигнала
# 🔍 MEME/USDT
# ⛔ MEME/USDT: нет сигнала
# 🔍 MEMEFI/USDT
# ⛔ MEMEFI/USDT: нет сигнала
# ⏩ MENGO/USDT: low volume
# ...
# ⛔ ASTR/USDT: нет сигнала
# 🔍 ASTER/USDT
# ⛔ ASTER/USDT: контекст sideways — пропуск
# 🔍 ATH/USDT
# ⛔ ATH/USDT: нет сигнала
# 🔍 ATOM/USDT
# ⛔ ATOM/USDT: нет сигнала
# 🔍 AUCTION/USDT
# ⛔ AUCTION/USDT: нет сигнала
# 🔍 AVAX/USDT
# ⛔ AVAX/USDT: нет сигнала
# 🔍 AVNT/USDT
# ⛔ AVNT/USDT: нет сигнала
# 🔍 AXS/USDT
# ⛔ AXS/USDT: нет сигнала
# 🔍 BABYDOGE/USDT
# ⛔ BABYDOGE/USDT: нет сигнала
# 🔍 BABY/USDT
# ⛔ BABY/USDT: нет сигнала
# 🔍 BADGER/USDT
# ⛔ BADGER/USDT: нет сигнала
# ⏩ BAL/USDT: low volume
# ⏩ BAND/USDT: low volume
# 🔍 BANANA/USDT
# ⛔ BANANA/USDT: нет сигнала
# 🔍 BARD/USDT
# ⛔ BARD/USDT: нет сигнала
# 🔍 BAT/USDT
# ⛔ BAT/USDT: нет сигнала
# 🔍 BERA/USDT
# ⛔ BERA/USDT: нет сигнала
# 🔍 BETH/USDT
# ⛔ BETH/USDT: нет сигнала
# ⏩ BICO/USDT: low volume
# 🔍 BIGTIME/USDT
# ⛔ BIGTIME/USDT: нет сигнала
# 🔍 BIO/USDT
# ⛔ BIO/USDT: нет сигнала
# 🔍 BLUR/USDT
# ⛔ BLUR/USDT: нет сигнала
# 🔍 BNB/USDT
# ⛔ BNB/USDT: нет сигнала
# ⏩ BNT/USDT: low volume
# 🔍 BOME/USDT
# ⛔ BOME/USDT: нет сигнала
# 🔍 BONK/USDT
# ⛔ BONK/USDT: нет сигнала
# 🔍 CATI/USDT
# ⛔ CATI/USDT: нет сигнала
# 🔍 CAT/USDT
# ⛔ CAT/USDT: нет сигнала
# 🔍 CELO/USDT
# ⛔ CELO/USDT: нет сигнала
# ⏩ CELR/USDT: low volume
# 🔍 CETUS/USDT
# ⛔ CETUS/USDT: нет сигнала
# 🔍 CFG/USDT
# ⛔ CFG/USDT: нет сигнала
# 🔍 CFX/USDT
# ⛔ CFX/USDT: нет сигнала
# 🔍 CHZ/USDT
# ⛔ CHZ/USDT: нет сигнала
# ⏩ CITY/USDT: low volume
# 🔍 CLV/USDT
# ⛔ CLV/USDT: нет сигнала
# 🔍 COMP/USDT
# ⛔ COMP/USDT: нет сигнала
# 🔍 CORE/USDT
# ⛔ CORE/USDT: нет сигнала
# 🔍 CRO/USDT
# ⛔ CRO/USDT: нет сигнала
# 🔍 CRV/USDT
# ⛔ CRV/USDT: нет сигнала
# 🔍 CSPR/USDT
# ⛔ CSPR/USDT: нет сигнала
# 🔍 CTC/USDT
# ⛔ CTC/USDT: нет сигнала
# 🔍 CVC/USDT
# ⛔ CVC/USDT: нет сигнала
# 🔍 CVX/USDT
# ⛔ CVX/USDT: нет сигнала
# 🔍 CXT/USDT
# ⛔ CXT/USDT: нет сигнала
# 🔍 DAI/USDT
# ⛔ DAI/USDT: нет сигнала
# ⏩ DAO/USDT: low volume
# 🔍 DEGEN/USDT
# ⛔ DEGEN/USDT: нет сигнала
# ⏩ DEP/USDT: low volume
# ⏩ DGB/USDT: low volume
# 🔍 DOGS/USDT
# ⛔ DOGS/USDT: нет сигнала
# 🔍 DOOD/USDT
# ⛔ DOOD/USDT: контекст sideways — пропуск
# ⏩ DORA/USDT: low volume
# 🔍 DOT/USDT
# ⛔ DOT/USDT: нет сигнала
# 🔍 DUCK/USDT
# ⛔ DUCK/USDT: нет сигнала
# 🔍 DYDX/USDT
# ⛔ DYDX/USDT: нет сигнала
# ⏩ EGLD/USDT: low volume
# 🔍 EIGEN/USDT
# ⛔ EIGEN/USDT: нет сигнала
# ⏩ ELF/USDT: low volume
# ⏩ ELON/USDT: low volume
# 🔍 ENA/USDT
# ⛔ ENA/USDT: нет сигнала
# ⏩ ENJ/USDT: low volume
# 🔍 ENS/USDT
# ⛔ ENS/USDT: нет сигнала
# 🔍 ETC/USDT
# ⛔ ETC/USDT: нет сигнала
# 🔍 ETHW/USDT
# ⛔ ETHW/USDT: нет сигнала
# 🔍 ETHFI/USDT
# ⛔ ETHFI/USDT: нет сигнала
# 🔍 FET/USDT
# ⛔ FET/USDT: нет сигнала
# 🔍 FIL/USDT
# ⛔ FIL/USDT: нет сигнала
# 🔍 FLM/USDT
# ⛔ FLM/USDT: нет сигнала
# 🔍 FLOW/USDT
# ⛔ FLOW/USDT: нет сигнала
# 🔍 FLOKI/USDT
# ⛔ FLOKI/USDT: нет сигнала
# 🔍 FLR/USDT
# ⛔ FLR/USDT: нет сигнала
# 🔍 FLUID/USDT
# ⛔ FLUID/USDT: нет сигнала
# ⏩ FOXY/USDT: low volume
# ⏩ FXS/USDT: low volume
# ⏩ G/USDT: low volume
# 🔍 GALA/USDT
# ⛔ GALA/USDT: нет сигнала
# ⏩ GALFT/USDT: low volume
# 🔍 GAS/USDT
# ⛔ GAS/USDT: нет сигнала
# ⏩ GEAR/USDT: low volume
# ⏩ GHST/USDT: low volume
# 🔍 GLM/USDT
# ⛔ GLM/USDT: нет сигнала
# 🔍 GMT/USDT
# ⛔ GMT/USDT: нет сигнала
# 🔍 GMX/USDT
# ⛔ GMX/USDT: нет сигнала
# 🔍 GOAT/USDT
# ⛔ GOAT/USDT: нет сигнала
# 🔍 GODS/USDT
# ⛔ GODS/USDT: нет сигнала
# 🔍 GRT/USDT
# ⛔ GRT/USDT: нет сигнала
# 🔍 HBAR/USDT
# ⛔ HBAR/USDT: нет сигнала
# 🔍 HMSTR/USDT
# ⛔ HMSTR/USDT: нет сигнала
# 🔍 HUMA/USDT
# ⛔ HUMA/USDT: нет сигнала
# 🔍 ICE/USDT
# ⛔ ICE/USDT: нет сигнала
# 🔍 ICP/USDT
# ⛔ ICP/USDT: нет сигнала
# ⏩ ICX/USDT: low volume
# ⏩ ID/USDT: low volume
# ⏩ ILV/USDT: low volume
# 🔍 IMX/USDT
# ⛔ IMX/USDT: нет сигнала
# 🔍 INJ/USDT
# ⛔ INJ/USDT: нет сигнала
# 🔍 IOST/USDT
# ⛔ IOST/USDT: нет сигнала
# 🔍 IOTA/USDT
# ⛔ IOTA/USDT: нет сигнала
# 🔍 IP/USDT
# ⛔ IP/USDT: нет сигнала
# 🔍 J/USDT
# ⛔ J/USDT: нет сигнала
# 🔍 JITOSOL/USDT
# ⛔ JITOSOL/USDT: нет сигнала
# ⏩ JOE/USDT: low volume
# 🔍 JTO/USDT
# ⛔ JTO/USDT: нет сигнала
# 🔍 JUP/USDT
# ⛔ JUP/USDT: нет сигнала
# 🔍 KAIA/USDT
# ⛔ KAIA/USDT: нет сигнала
# 🔍 KAITO/USDT
# ⛔ KAITO/USDT: нет сигнала
# ⏩ KDA/USDT: low volume
# 🔍 KMNO/USDT
# ⛔ KMNO/USDT: нет сигнала
# ⏩ KNC/USDT: low volume
# 🔍 KSM/USDT
# ⛔ KSM/USDT: нет сигнала
# 🔍 LAT/USDT
# ⛔ LAT/USDT: нет сигнала
# 🔍 LAYER/USDT
# ⛔ LAYER/USDT: нет сигнала
# 🔍 LDO/USDT
# ⛔ LDO/USDT: нет сигнала
# ⏩ LEO/USDT: low volume
# 🔍 LINK/USDT
# ⛔ LINK/USDT: нет сигнала
# ⏩ LOOKS/USDT: low volume
# 🔍 LPT/USDT
# ⛔ LPT/USDT: нет сигнала
# 🔍 LQTY/USDT
# ⛔ LQTY/USDT: нет сигнала
# ⏩ LRC/USDT: low volume
# ⏩ LSK/USDT: low volume
# 🔍 LTC/USDT
# ⛔ LTC/USDT: нет сигнала
# 🔍 LUNA/USDT
# ⛔ LUNA/USDT: нет сигнала
# 🔍 MAGIC/USDT
# ⛔ MAGIC/USDT: нет сигнала
# 🔍 MAJOR/USDT
# ⛔ MAJOR/USDT: нет сигнала
# 🔍 MANA/USDT
# ⛔ MANA/USDT: нет сигнала
# 🔍 MASK/USDT
# ⛔ MASK/USDT: нет сигнала
# 🔍 ME/USDT
# ⛔ ME/USDT: нет сигнала
# 🔍 MEME/USDT
# ⛔ MEME/USDT: нет сигнала
# 🔍 MEMEFI/USDT
# ⛔ MEMEFI/USDT: нет сигнала
# ⏩ MENGO/USDT: low volume
# 🔍 MERL/USDT
# ⛔ MERL/USDT: нет сигнала
# 🔍 METIS/USDT
# ⛔ METIS/USDT: нет сигнала
# 🔍 MEW/USDT
# ⛔ MEW/USDT: нет сигнала
# 🔍 MINA/USDT
# ⛔ MINA/USDT: нет сигнала
# ⏩ MLN/USDT: low volume
# 🔍 MOODENG/USDT
# ⛔ MOODENG/USDT: нет сигнала
# 🔍 MORPHO/USDT
# ⛔ MORPHO/USDT: нет сигнала
# 🔍 MOVE/USDT
# ⛔ MOVE/USDT: нет сигнала
# ⏩ NAVX/USDT: low volume
# ⏩ NC/USDT: low volume
# 🔍 NEAR/USDT
# ⛔ NEAR/USDT: нет сигнала
# 🔍 NEIRO/USDT
# ⛔ NEIRO/USDT: нет сигнала
# 🔍 NEO/USDT
# ⛔ NEO/USDT: нет сигнала
# ⏩ NFT/USDT: low volume
# 🔍 NMR/USDT
# ⛔ NMR/USDT: нет сигнала
# 🔍 NOT/USDT
# ⛔ NOT/USDT: нет сигнала
# ⏩ OAS/USDT: low volume
# 🔍 OKSOL/USDT
# ⛔ OKSOL/USDT: нет сигнала
# 🔍 OL/USDT
# ⛔ OL/USDT: нет сигнала
# 🔍 OM/USDT
# ⛔ OM/USDT: нет сигнала
# 🔍 OMI/USDT
# ⛔ OMI/USDT: нет сигнала
# 🔍 ONDO/USDT
# ⛔ ONDO/USDT: нет сигнала
# ⏩ ONE/USDT: low volume
# 🔍 ONT/USDT
# ⛔ ONT/USDT: нет сигнала
# 🔍 OP/USDT
# ⛔ OP/USDT: нет сигнала
# ⏩ ORBS/USDT: low volume
# 🔍 ORDI/USDT
# ⛔ ORDI/USDT: нет сигнала
# 🔍 PARTI/USDT
# ⛔ PARTI/USDT: нет сигнала
# 🔍 PAXG/USDT
# ⛔ PAXG/USDT: нет сигнала
# 🔍 PENDLE/USDT
# ⛔ PENDLE/USDT: нет сигнала
# 🔍 PENGU/USDT
# ⛔ PENGU/USDT: нет сигнала
# 🔍 PEOPLE/USDT
# ⛔ PEOPLE/USDT: нет сигнала
# 🔍 PEPE/USDT
# ⛔ PEPE/USDT: нет сигнала
# ⏩ PERP/USDT: low volume
# 🔍 PHA/USDT
# ⛔ PHA/USDT: нет сигнала
# 🔍 PI/USDT
# ⛔ PI/USDT: нет сигнала
# 🔍 PIXEL/USDT
# ⛔ PIXEL/USDT: нет сигнала
# 🔍 PNUT/USDT
# ⛔ PNUT/USDT: нет сигнала
# 🔍 POL/USDT
# ⛔ POL/USDT: нет сигнала
# ⏩ POR/USDT: low volume
# 🔍 PRCL/USDT
# ⛔ PRCL/USDT: нет сигнала
# 🔍 PROMPT/USDT
# ⛔ PROMPT/USDT: нет сигнала
# 🔍 PROVE/USDT
# ⛔ PROVE/USDT: контекст sideways — пропуск
# 🔍 PSTAKE/USDT
# ⛔ PSTAKE/USDT: нет сигнала
# 🔍 PYTH/USDT
# ⛔ PYTH/USDT: нет сигнала
# 🔍 PYUSD/USDT
# ⛔ PYUSD/USDT: нет сигнала
# 🔍 QTUM/USDT
# ⛔ QTUM/USDT: нет сигнала
# ⏩ RACA/USDT: low volume
# 🔍 RAY/USDT
# ⛔ RAY/USDT: нет сигнала
# 🔍 RDNT/USDT
# ⛔ RDNT/USDT: нет сигнала
# 🔍 RENDER/USDT
# ⛔ RENDER/USDT: нет сигнала
# 🔍 RESOLV/USDT
# ⛔ RESOLV/USDT: нет сигнала
# 🔍 RIO/USDT
# ⛔ RIO/USDT: нет сигнала
# ⏩ RON/USDT: low volume
# ⏩ RPL/USDT: low volume
# 🔍 RSR/USDT
# ⛔ RSR/USDT: нет сигнала
# 🔍 RSS3/USDT
# ⛔ RSS3/USDT: нет сигнала
# 🔍 RVN/USDT
# ⛔ RVN/USDT: нет сигнала
# 🔍 S/USDT
# ⛔ S/USDT: нет сигнала
# 🔍 SAFE/USDT
# ⛔ SAFE/USDT: нет сигнала
# 🔍 SAHARA/USDT
# ⛔ SAHARA/USDT: нет сигнала
# 🔍 SAND/USDT
# ⛔ SAND/USDT: нет сигнала
# 🔍 SATS/USDT
# ⛔ SATS/USDT: нет сигнала
# 🔍 SCR/USDT
# ⛔ SCR/USDT: нет сигнала
# 🔍 SD/USDT
# ⛔ SD/USDT: нет сигнала
# 🔍 SHIB/USDT
# ⛔ SHIB/USDT: нет сигнала
# 🔍 SKL/USDT
# ⛔ SKL/USDT: нет сигнала
# 🔍 SKY/USDT
# ⛔ SKY/USDT: нет сигнала
# 🔍 SLERF/USDT
# ⛔ SLERF/USDT: нет сигнала
# ⏩ SLP/USDT: low volume
# 🔍 SNT/USDT
# ⛔ SNT/USDT: нет сигнала
# 🔍 SNX/USDT
# ⛔ SNX/USDT: нет сигнала
# 🔍 SONIC/USDT
# ⛔ SONIC/USDT: нет сигнала
# 🔍 SOPH/USDT
# ⛔ SOPH/USDT: нет сигнала
# 🔍 SPK/USDT
# ⛔ SPK/USDT: нет сигнала
# ⏩ SPURS/USDT: low volume
# 🔍 SSV/USDT
# ⛔ SSV/USDT: нет сигнала
# 🔍 STETH/USDT
# ⛔ STETH/USDT: нет сигнала
# ⏩ STORJ/USDT: low volume
# 🔍 STRK/USDT
# ⛔ STRK/USDT: нет сигнала
# 🔍 STX/USDT
# ⛔ STX/USDT: нет сигнала
# 🔍 SUI/USDT
# ⛔ SUI/USDT: нет сигнала
# 🔍 SUSHI/USDT
# ⛔ SUSHI/USDT: нет сигнала
# 🔍 SWEAT/USDT
# ⛔ SWEAT/USDT: нет сигнала
# ⏩ SWFTC/USDT: low volume
# ⏩ T/USDT: low volume
# 🔍 THETA/USDT
# ⛔ THETA/USDT: нет сигнала
# 🔍 TIA/USDT
# ⛔ TIA/USDT: нет сигнала
# 🔍 TNSR/USDT
# ⛔ TNSR/USDT: нет сигнала
# 🔍 TON/USDT
# ⛔ TON/USDT: нет сигнала
# 🔍 TOSHI/USDT
# ⛔ TOSHI/USDT: нет сигнала
# ⏩ TRA/USDT: low volume
# 🔍 TRB/USDT
# ⛔ TRB/USDT: нет сигнала
# 🔍 TRUMP/USDT
# ⛔ TRUMP/USDT: нет сигнала
# 🔍 TRX/USDT
# ⛔ TRX/USDT: нет сигнала
# 🔍 TURBO/USDT
# ⛔ TURBO/USDT: нет сигнала
# ⏩ ULTI/USDT: low volume
# 🔍 UMA/USDT
# ⛔ UMA/USDT: нет сигнала
# 🔍 UNI/USDT
# ⛔ UNI/USDT: нет сигнала
# 🔍 USDC/USDT
# ⛔ USDC/USDT: нет сигнала
# 🔍 USDG/USDT
# ⛔ USDG/USDT: нет сигнала
# ⏩ USD1/USDT: low volume
# 🔍 UXLINK/USDT
# ⛔ UXLINK/USDT: нет сигнала
# 🔍 VELO/USDT
# ⛔ VELO/USDT: нет сигнала
# ⏩ VELODROME/USDT: low volume
# 🔍 VINE/USDT
# ⛔ VINE/USDT: нет сигнала
# 🔍 VRA/USDT
# ⛔ VRA/USDT: нет сигнала
# 🔍 W/USDT
# ⛔ W/USDT: нет сигнала
# ⏩ WAXP/USDT: low volume
# 🔍 WCT/USDT
# ⛔ WCT/USDT: нет сигнала
# 🔍 WIF/USDT
# ⛔ WIF/USDT: нет сигнала
# 🔍 WINTOKEN/USDT
# ⛔ WINTOKEN/USDT: нет сигнала
# 🔍 WLD/USDT
# ⛔ WLD/USDT: нет сигнала
# 🔍 WOO/USDT
# ⛔ WOO/USDT: нет сигнала
# 🔍 XAUT/USDT
# ⛔ XAUT/USDT: нет сигнала
# 🔍 XCH/USDT
# ⛔ XCH/USDT: нет сигнала
# 🔍 XLM/USDT
# ⛔ XLM/USDT: нет сигнала
# 🔍 XPL/USDT
# ⛔ XPL/USDT: нет сигнала
# 🔍 XTZ/USDT
# ⛔ XTZ/USDT: нет сигнала
# 🔍 YB/USDT
# ⛔ YB/USDT: нет сигнала
# 🔍 YFI/USDT
# ⛔ YFI/USDT: нет сигнала
# 🔍 YGG/USDT
# ⛔ YGG/USDT: нет сигнала
# 🔍 ZBCN/USDT
# ⛔ ZBCN/USDT: нет сигнала
# 🔍 ZENT/USDT
# ⛔ ZENT/USDT: нет сигнала
# 🔍 ZETA/USDT
# ⛔ ZETA/USDT: нет сигнала
# 🔍 ZEUS/USDT
# ⛔ ZEUS/USDT: нет сигнала
# 🔍 ZIL/USDT
# ⛔ ZIL/USDT: нет сигнала
# 🔍 ZK/USDT
# ⛔ ZK/USDT: нет сигнала
# 🔍 ZKJ/USDT
# ⛔ ZKJ/USDT: нет сигнала
# 🔍 ZORA/USDT
# ⛔ ZORA/USDT: контекст sideways — пропуск
# 🔍 ZRO/USDT
# ⛔ ZRO/USDT: нет сигнала
# ⏩ ZRX/USDT: low volume
# ⏩ BTC/USDT:USDT-251024: low volume
# ⏩ BTC/USDT:USDT-251031: low volume
# ⏩ BTC/USDT:USDT-251128: low volume
# ⏩ BTC/USDT:USDT-251226: low volume
# ⏩ BTC/USDT:USDT-260327: low volume
# ⏩ BTC/USDT:USDT-260626: low volume
# ⏩ ETH/USDT:USDT-251024: low volume
# ⏩ ETH/USDT:USDT-251031: low volume
# ⏩ ETH/USDT:USDT-251226: low volume
# ⏩ ETH/USDT:USDT-260327: low volume
# ⏩ BTC/USDT:USDT: low volume
# ⏩ ETH/USDT:USDT: low volume
# ⏩ OKB/USDT:USDT: low volume
# ⏩ SOL/USDT:USDT: low volume
# ⏩ DOGE/USDT:USDT: low volume
# ⏩ XRP/USDT:USDT: low volume
# ⏩ BCH/USDT:USDT: low volume
# ⏩ PUMP/USDT:USDT: low volume
# ⏩ WLFI/USDT:USDT: low volume
# ⏩ LINEA/USDT:USDT: low volume
# ⏩ 0G/USDT:USDT: low volume
# ⏩ 1INCH/USDT:USDT: low volume
# ⏩ 2Z/USDT:USDT: low volume
# ⏩ A/USDT:USDT: low volume
# ⏩ AAVE/USDT:USDT: low volume
# ⏩ ACE/USDT:USDT: low volume
# ⏩ ACH/USDT:USDT: low volume
# ⏩ ACT/USDT:USDT: low volume
# ⏩ ADA/USDT:USDT: low volume
# ⏩ AERO/USDT:USDT: low volume
# ⏩ AEVO/USDT:USDT: low volume
# ⏩ AGLD/USDT:USDT: low volume
# ⏩ AI16Z/USDT:USDT: low volume
# ⏩ AIXBT/USDT:USDT: low volume
# ⏩ ALGO/USDT:USDT: low volume
# ⏩ ANIME/USDT:USDT: low volume
# ⏩ APE/USDT:USDT: low volume
